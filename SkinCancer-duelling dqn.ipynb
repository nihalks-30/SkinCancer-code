# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import os.path
import sys
import numpy as np
import math
import sklearn.metrics as metrics
from tqdm import tqdm
from gym import Env, spaces
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split


from tensorflow.python.keras import backend
from tensorflow.keras.backend import clear_session


import time
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="google.protobuf")

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import csv

import tensorflow as tf
import tensorflow.compat.v1 as tf1
import tensorflow.keras as K

from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = str(0)


from sklearn.feature_extraction.text import CountVectorizer

# %%
def read_and_decode(dataset, batch_size, is_training, data_size,n_patients):
    if is_training:
        dataset = dataset.shuffle(buffer_size=data_size, reshuffle_each_iteration=True)
        dataset = dataset.batch(batch_size, drop_remainder=False)
        dataset = dataset.repeat(None)
    else:
        dataset = dataset.prefetch(buffer_size=data_size // batch_size)
        dataset = dataset.batch(batch_size, drop_remainder=False)
        dataset = dataset.repeat(None)
    return dataset

# %%
def create_q_model(n_classes, n_words, n_actions):
    # Standard input for your combined features
    inputs = K.layers.Input(shape=(n_classes,))

    # Feature extraction (matching your current logic)
    feat = K.layers.Lambda(lambda x: x[:, 0:n_classes - n_words])(inputs)
    prob = K.layers.Lambda(lambda x: x[:, n_classes - n_words:n_classes])(inputs)
    
    # Shared Dense Layer
    shared = K.layers.Dense(256, activation="relu")(feat)
    shared = K.layers.Dropout(0.05)(shared)
    
    # Concatenate with CNN probabilities
    shared_combined = K.layers.Concatenate(axis=1)([shared, prob])
    
    # --- Dueling Streams ---
    
    # 1. Value Stream (V): Estimating the value of being in the current state
    v_stream = K.layers.Dense(128, activation="relu")(shared_combined)
    value = K.layers.Dense(1, activation=None)(v_stream)
    
    # 2. Advantage Stream (A): Estimating the relative benefit of each diagnostic action
    a_stream = K.layers.Dense(128, activation="relu")(shared_combined)
    advantage = K.layers.Dense(n_actions, activation=None)(a_stream)
    
    # 3. Aggregation Layer
    # Formula: Q(s,a) = V(s) + (A(s,a) - Mean(A(s,a)))
    def aggregate_layer(vectors):
        v, a = vectors
        return v + (a - tf.reduce_mean(a, axis=1, keepdims=True))
    
    q_values = K.layers.Lambda(aggregate_layer)([value, advantage])
    
    return K.Model(inputs=inputs, outputs=q_values)

# %%
def initialize_clinical_practice(clinical_cases_feat,clinical_cases_labels,dataset_size,n_classes,is_training,n_patients,set_distribution):

    if is_training:
        _, counts = np.unique(clinical_cases_labels, return_counts=True)

        akiec = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 0), axis=0))
        akiec_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 0), axis=0))

        bcc = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 1), axis=0))
        bcc_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 1), axis=0))

        bkl = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 2), axis=0))
        bkl_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 2), axis=0))

        df = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 3), axis=0))
        df_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 3), axis=0))

        mel = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 4), axis=0))
        mel_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 4), axis=0))

        nv = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 5), axis=0))
        nv_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 5), axis=0))

        vasc = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 6), axis=0))
        vasc_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 6), axis=0))

        akiec_set = tf.data.Dataset.from_tensor_slices((akiec, akiec_labels)).shuffle(buffer_size=counts[0],
                                                                                      reshuffle_each_iteration=True).repeat()
        bcc_set = tf.data.Dataset.from_tensor_slices((bcc, bcc_labels)).shuffle(buffer_size=counts[1],
                                                                                reshuffle_each_iteration=True).repeat()
        bkl_set = tf.data.Dataset.from_tensor_slices((bkl, bkl_labels)).shuffle(buffer_size=counts[2],
                                                                                reshuffle_each_iteration=True).repeat()
        df_set = tf.data.Dataset.from_tensor_slices((df, df_labels)).shuffle(buffer_size=counts[3],
                                                                             reshuffle_each_iteration=True).repeat()
        mel_set = tf.data.Dataset.from_tensor_slices((mel, mel_labels)).shuffle(buffer_size=counts[4],
                                                                                reshuffle_each_iteration=True).repeat()
        nv_set = tf.data.Dataset.from_tensor_slices((nv, nv_labels)).shuffle(buffer_size=counts[5],
                                                                             reshuffle_each_iteration=True).repeat()
        vasc_set = tf.data.Dataset.from_tensor_slices((vasc, vasc_labels)).shuffle(buffer_size=counts[6],
                                                                                   reshuffle_each_iteration=True).repeat()

        dataset_train = tf.data.Dataset.sample_from_datasets([akiec_set, bcc_set, bkl_set, df_set, mel_set, nv_set, vasc_set], weights=set_distribution)
        dataset_train = dataset_train.batch(1)

    else:
        dataset_train = tf.data.Dataset.from_tensor_slices((clinical_cases_feat,clinical_cases_labels))

        dataset_train = read_and_decode(dataset_train, 1, is_training, dataset_size,n_patients)

    patients = iter(dataset_train)

    return patients

# %%
 def get_next_patient(patients):
        patient_scores,patient_diagnostics = patients.get_next()
    
        return np.squeeze(patient_scores),patient_diagnostics.numpy()[0]

# %%
class Dermatologist(Env):

    def __init__(self,patients,n_classes,vocab):
        # Actions we can take, either skin lesion classes or don't know
        self.action_space = spaces.Discrete(len(vocab))
        # Observation space - softmax + features after GAP
        self.observation_space = spaces.Box(-1*math.inf*np.ones((n_classes,)),math.inf*np.ones((n_classes,)))
        # Initialize state
        n_state,n_gt = get_next_patient(patients)
        self.state = n_state
        self.revised_state = self.state
        self.gt = n_gt
        # Set shower length
        self.number_of_patients = 0

    def step(self,patients,n_patients,vocab,action):
        ### UNKN_reward = -1
        reward_table = np.array([[2,-2,-3,	-3,	-2,	-3,	-3,	-1],
                                 [-2,3,	-4,	-4,	-2,	-4,	-4,	-1],
                                 [-2,-2, 1,	-2,	-3,	-2,	-2,	-1],
                                 [-2,-2,-2,	1,-3,	-2,	-2,	-1],
                                 [-4, -3, -12, -5, 10, -12, -5, -1],
                                 [-2,-2,-2,	-2,	-3,	1,	-2,	-1],
                                 [-2,-2,-2,	-2,	-3,	-2,	1,	-1],
                                 ],np.float32)

        ### UNKN_reward = 0
        # reward_table = np.array([[2, -2, -3, -3, -2, -3, -3, 0],
        #                          [-2, 3, -4, -4, -2, -4, -4, 0],
        #                          [-2, -2, 1, -2, -3, -2, -2, 0],
        #                          [-2, -2, -2, 1, -3, -2, -2, 0],
        #                          [-4, -3, -5, -5, 5, -5, -5, 0],
        #                          [-2, -2, -2, -2, -3, 1, -2, 0],
        #                          [-2, -2, -2, -2, -3, -2, 1, 0],
        #                          ], np.float32)

        ### UNKN_reward = 0.5
        # reward_table = np.array([[2, -2, -3, -3, -2, -3, -3, 0.5],
        #                          [-2, 3, -4, -4, -2, -4, -4, 0.5],
        #                          [-2, -2, 1, -2, -3, -2, -2, 0.5],
        #                          [-2, -2, -2, 1, -3, -2, -2, 0.5],
        #                          [-4, -3, -5, -5, 5, -5, -5, 0.5],
        #                          [-2, -2, -2, -2, -3, 1, -2, 0.5],
        #                          [-2, -2, -2, -2, -3, -2, 1, 0.5],
        #                          ], np.float32)

        
        self.revised_state = tf.one_hot(action,len(vocab))

        reward = reward_table[self.gt,action]

        n_state, n_gt = get_next_patient(patients)

        old_gt = self.gt

        self.state = n_state
        self.gt = n_gt

        self.number_of_patients += 1

        # Check if checking patients is done
        if self.number_of_patients >= n_patients:# or old_gt != action:
            done = 1
        else:
            done = 0

            #reward += 1000

        return self.revised_state, self.state, reward,done,old_gt

    def reset(self,clinical_cases_feat,clinical_cases_labels,n_classes,dataset_size,vocab,is_training,n_patients,sample_distribution):
        # Reset clinical practice
        patients = initialize_clinical_practice(clinical_cases_feat,clinical_cases_labels, dataset_size,n_classes,is_training,n_patients,sample_distribution)
        n_state, n_gt = get_next_patient(patients)
        self.state = n_state
        self.revised_state = self.state
        self.gt = n_gt
        # Reset new practice
        self.number_of_patients = 0

        return self.state,patients

# %%
def main(_):
    gamma = 0.99  # Discount factor for past rewards
    epsilon = 0.2  # Epsilon greedy parameter
    epsilon_min = 0.1  # Minimum epsilon greedy parameter
    epsilon_max = 0.2  # Maximum epsilon greedy parameter
    epsilon_interval = (epsilon_max - epsilon_min)  # Rate at which to reduce chance of random action being taken

    #### Import Datasets ####
    tf1.enable_eager_execution()

    database = pd.read_csv('data/vectorDB.csv')

    print(database)

    database.head()

    labels = np.asarray(database['dx'])

    print(labels)

    labels[labels == 'scc'] = 'akiec'

    le = preprocessing.LabelEncoder()

    le.fit(labels)

    vocab = le.classes_

    n_words = len(vocab)

    if Flags.use_unknown:
        vocab = np.append(vocab,'unkn')

    features1 = np.load("data/nmed_rn34_ham10k_vectors.npy")

    features2 = pd.read_csv("data/vectorDB.csv")

    features2.pop('dx')

    features2 = np.asarray(features2, dtype='float32')

    features = np.concatenate([features1,features2],axis=1)
    

    _, counts = np.unique(labels, return_counts=True)

    print(counts)

    counts = counts/np.sum(counts)
        

    labels_cat = le.transform(labels)

    print(labels_cat.dtype)

    train_feat, val_feat, train_labels, val_labels = train_test_split(features, labels_cat, test_size=0.2,
                                                                      random_state=111,stratify = labels_cat)


    _, count_train = np.unique(val_labels, return_counts=True)

    print(count_train)

    patients = initialize_clinical_practice(train_feat,train_labels,train_labels.shape[0],True,n_words,Flags.n_patients,counts)

    derm = Dermatologist(patients,n_words,vocab)

    q_network = create_q_model(derm.state.shape[0],n_words,Flags.n_actions)

    q_network.summary()

    target_network = create_q_model(derm.state.shape[0],n_words,Flags.n_actions)

    optimizer = K.optimizers.Adam(learning_rate=0.025, clipnorm=1.0)


    # Experience replay buffers
    action_history = []
    state_history = []
    state_next_history = []
    rewards_history = []
    done_history = []
    episode_reward_history = []
    episode_val_reward_history = []
    validation_bacc_history = []
    mel_history = []
    unk_history = []
    cnn_history = []
    best_bacc = 0
    best_reward = -1*math.inf
    iter_count = 0
    # Number of frames to take random action and observe output
    epsilon_random_frames = 20
    # Number of frames for exploration
    epsilon_greedy_frames = 100000.0
    # Maximum replay length
    max_memory_length = 10000
    # Train the model after 4 actions
    update_after_actions = 10
    # How often to update the target network
    update_target_network = train_feat.shape[0]
    # Using huber loss for stability
    loss_function = K.losses.Huber()

    for episode in range(Flags.n_episodes):
        i = 1
        print('Starting episode ',episode)

        done = False
        episode_score = 0

        episode_val_score = 0

        state = derm.state
        #state = np.concatenate([derm.state, [0]])
        n_not_random = 0
        while not done:
            try:
                iter_count += 1

                # Use epsilon-greedy for exploration
                if iter_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
                    action = derm.action_space.sample()
                else:
                    state_tensor = tf.convert_to_tensor(state)
                    state_tensor = tf.expand_dims(state_tensor, 0)
                    action_probs = q_network(state_tensor, training=False)
                    # Take best action
                    action = tf.argmax(action_probs[0]).numpy()

                    n_not_random += 1

            

                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                revised_state,n_state,reward,done,_ = derm.step(patients,Flags.n_patients,vocab,action)

                episode_score += reward

                # Save actions and states in replay buffer
                action_history.append(action)
                state_history.append(state)
                state_next_history.append(n_state)
                done_history.append(done)
                rewards_history.append(reward)
                state = n_state

                i += 1
                # Update every fourth frame
                # Update every fourth frame
                if iter_count % update_after_actions == 0 and len(done_history) > 100:
                    # Get indices of samples for replay buffers
                    indices = np.random.choice(range(len(done_history)), size=100)

                    # Using list comprehension to sample from replay buffer
                    state_sample = np.array([state_history[i] for i in indices])
                    state_next_sample = np.array([state_next_history[i] for i in indices])
                    rewards_sample = np.array([rewards_history[i] for i in indices], dtype=np.float32)
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor([float(done_history[i]) for i in indices])

                    # ---------------------------------------------------------
                    # [START] DOUBLE DQN LOGIC (DDQN)
                    # ---------------------------------------------------------
                    
                    # 1. Action SELECTION: Use the MAIN network to pick the best action for the next state
                    next_q_values_main = q_network.predict(state_next_sample, verbose=0)
                    best_next_actions = tf.argmax(next_q_values_main, axis=1)

                    # 2. Action EVALUATION: Use the TARGET network to calculate the value of those actions
                    next_q_values_target = target_network.predict(state_next_sample, verbose=0)
                    
                    # We need to gather the Q-values from the target network corresponding 
                    # specifically to the actions chosen by the main network.
                    # We create indices [[0, action_0], [1, action_1], ...]
                    batch_indices = tf.range(tf.shape(best_next_actions)[0], dtype=tf.int64)
                    action_indices = tf.stack([batch_indices, best_next_actions], axis=1)
                    
                    # Extract the Q-values for the chosen actions
                    future_rewards = tf.gather_nd(next_q_values_target, action_indices)

                    # 3. Calculate the Target Q-Value
                    # Q_target = r + gamma * Q_target(s', argmax Q_main(s', a'))
                    updated_q_values = rewards_sample + gamma * future_rewards
                    
                    # ---------------------------------------------------------
                    # [END] DOUBLE DQN LOGIC
                    # ---------------------------------------------------------

                    # If final frame set the last value to -1 (Terminal state handling)
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values
                    masks = tf.one_hot(action_sample, len(vocab))

                    with tf.GradientTape() as tape:
                        # Train the model on the states and updated Q-values
                        q_values = q_network(state_sample, training=True)

                        # Apply the masks to the Q-values to get the Q-value for action taken
                        q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                        # Calculate loss between new Q-value and old Q-value
                        loss = loss_function(updated_q_values, q_action)

                    # Backpropagation
                    grads = tape.gradient(loss, q_network.trainable_variables)
                    optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

                if iter_count % update_target_network == 0:
                    # update the the target network with new weights
                    target_network.set_weights(q_network.get_weights())

                # Limit the state and reward history
                if len(rewards_history) > max_memory_length:
                    del rewards_history[:1]
                    del state_history[:1]
                    del state_next_history[:1]
                    del action_history[:1]
                    del done_history[:1]


            except tf.python.framework.errors_impl.OutOfRangeError:
                done = True
                break

        print('The episode duration was ',i-1)
        print('The episode reward was ',episode_score)
        print('The number of not random actions was ', n_not_random)
        # Update running reward to check condition for solving
        episode_reward_history.append(episode_score)

        ## Validation Phase ##
        state,patients_val = derm.reset(val_feat,val_labels, val_labels.shape[0], n_words, vocab,False,Flags.n_patients,counts)

        done = False

        error = np.array([])
        CNN_error = np.array([])
        true_label = np.array([])

        mel_count = 0

        unk_count = 0

        while not done:
            try:
                true_label = np.append(true_label, derm.gt)

                state_tensor = tf.convert_to_tensor(state)
                state_tensor = tf.expand_dims(state_tensor, 0)
                action_probs = q_network(state_tensor, training=False)
                # Take best action
                action = tf.argmax(action_probs[0]).numpy()

                error = np.append(error, action)

                if vocab[action] == 'mel':
                    mel_count += 1
                elif vocab[action] == 'unkn':
                    unk_count += 1

                _, state, reward, done,_ = derm.step(patients_val, val_labels.shape[0], vocab, action)


                episode_val_score += reward

            except tf.python.framework.errors_impl.OutOfRangeError:
                done = True
                break

        print('The reward of the validation episode was ', episode_val_score)
        print('The balanced accuracy was ', metrics.balanced_accuracy_score(true_label, error))
        episode_val_reward_history.append(episode_val_score)
        validation_bacc_history.append(metrics.balanced_accuracy_score(true_label, error))
        mel_history.append(mel_count)
        unk_history.append(unk_count)

        if best_bacc < metrics.balanced_accuracy_score(true_label, error):
            history_report_bacc = metrics.classification_report(true_label,error,digits=3, zero_division=0)
            history_cov_bacc = metrics.confusion_matrix(true_label,error)
            best_bacc = metrics.balanced_accuracy_score(true_label, error)
            q_network.save_weights('models/best_q_network_diagnosis_bacc.weights.h5')

        if best_reward < episode_val_score:
            history_cov_reward = metrics.confusion_matrix(true_label, error)
            history_report_reward = metrics.classification_report(true_label,error,digits=3, zero_division=0)
            best_reward = episode_val_score
            q_network.save_weights('models/best_q_network_diagnosis_reward.weights.h5')

        ##Return to train
        _,patients = derm.reset(train_feat,train_labels, train_labels.shape[0], n_words, vocab,True,Flags.n_patients,counts)

    q_network.save_weights('models/q_network_diagnosis_final.weights.h5')

    print('The scores for best validation BAcc are:')
    print(history_report_bacc)
    print(history_cov_bacc)
    print('The best BAcc was ',best_bacc)

    print('The scores for best validation Reward are:')
    print(history_report_reward)
    print(history_cov_reward)
    print('The best reward was ', best_reward)

    plt.figure(1)
    plt.plot(episode_reward_history)
    plt.xlabel('Episodes')
    plt.ylabel('Reward Per Episode - Train')
    plt.show()

    plt.figure(2)
    plt.plot(episode_val_reward_history)
    plt.xlabel('Episodes')
    plt.ylabel('Reward Per Episode - Val')
    plt.show()

    plt.figure(3)
    plt.plot(validation_bacc_history)
    plt.xlabel('Episodes')
    plt.ylabel('RL BAcc')
    plt.show()

    plt.figure(4)
    plt.plot(mel_history)
    plt.xlabel('Episodes')
    plt.ylabel('Number Melanoma Decisions')
    plt.show()

    plt.figure(5)
    plt.plot(unk_history)
    plt.xlabel('Episodes')
    plt.ylabel('Number of Unknown Decisions')
    plt.show()

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--n_patients',
        type=int,
        default= 100,
        help='Number of patients per episode.'
    )
    parser.add_argument(
        '--n_episodes',
        type=int,
        default= 150,
        help='Number of episodes to play'
    )
    parser.add_argument(
        '--use_unknown',
        type=bool,
        default=False,
        help='Whether to use unknown action or not distribution'
    )
    parser.add_argument(
        '--n_actions',
        type=int,
        default= 7,
        help='Number of episodes to play'
    )
    Flags, unparsed = parser.parse_known_args()
    tf1.app.run(main=main)
# Out:
#               akiec       bcc       bkl            df       mel        nv  \
# 0      1.239820e-04  0.001757  0.071755  2.613447e-02  0.004628  0.895575
# 1      1.564469e-03  0.000353  0.582653  1.401107e-02  0.000817  0.400582
# 2      7.310000e-07  0.000002  0.005028  5.290000e-07  0.002840  0.992129
# 3      3.012000e-03  0.027224  0.293466  3.917728e-02  0.062816  0.561710
# 4      1.044428e-03  0.007633  0.776036  3.400000e-05  0.197736  0.017514
# ...             ...       ...       ...           ...       ...       ...
# 10010  2.074046e-03  0.001095  0.002900  4.630000e-05  0.991719  0.000645
# 10011  9.210000e-06  0.000346  0.001581  4.070000e-05  0.308520  0.689383
# 10012  5.650000e-05  0.001307  0.977360  3.800000e-05  0.000746  0.020455
# 10013  3.850000e-06  0.000040  0.004911  2.747410e-04  0.214675  0.780093
# 10014  2.450000e-05  0.000041  0.013609  5.980000e-05  0.091868  0.894389
#
#                vasc   dx
# 0      2.630000e-05   nv
# 1      1.920000e-05   nv
# 2      4.690000e-07   nv
# 3      1.259401e-02   nv
# 4      1.840000e-06  mel
# ...             ...  ...
# 10010  1.519908e-03  mel
# 10011  1.203480e-04  mel
# 10012  3.710000e-05  bkl
# 10013  2.210000e-06   nv
# 10014  8.780000e-06   nv
#
# [10015 rows x 8 columns]
# ['nv' 'nv' 'nv' ... 'bkl' 'nv' 'nv']
# [ 327  514 1099  115 1113 6705  142]
# int64
# [  65  103  220   23  223 1341   28]
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 519)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 512)       │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │    131,328 │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 7)         │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 263)       │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     33,792 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     33,792 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1)         │        129 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 7)         │        903 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 7)         │          0 │ dense_6[0][0],    │
# │                     │                   │            │ dense_8[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 199,944 (781.03 KB)
#  Trainable params: 199,944 (781.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting episode  0
# The episode duration was  100
# The episode reward was  -205.0
# The number of not random actions was  61
# The reward of the validation episode was  -4766.0
# The balanced accuracy was  0.08362301382435611
# Starting episode  1
# WARNING:tensorflow:5 out of the last 161 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002A0781EBCE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0220 00:42:24.724529 26348 polymorphic_function.py:157] 5 out of the last 161 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002A0781EBCE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# The episode duration was  100
# The episode reward was  -108.0
# The number of not random actions was  83
# The reward of the validation episode was  -2484.0
# The balanced accuracy was  0.14285714285714285
# Starting episode  2
# The episode duration was  100
# The episode reward was  -96.0
# The number of not random actions was  83
# The reward of the validation episode was  -753.0
# The balanced accuracy was  0.37403449847575737
# Starting episode  3
# The episode duration was  100
# The episode reward was  -136.0
# The number of not random actions was  74
# The reward of the validation episode was  -348.0
# The balanced accuracy was  0.36134338934886273
# Starting episode  4
# The episode duration was  100
# The episode reward was  -49.0
# The number of not random actions was  77
# The reward of the validation episode was  -713.0
# The balanced accuracy was  0.2738790787920911
# Starting episode  5
# The episode duration was  100
# The episode reward was  -46.0
# The number of not random actions was  79
# The reward of the validation episode was  -684.0
# The balanced accuracy was  0.31617807234214357
# Starting episode  6
# The episode duration was  100
# The episode reward was  -68.0
# The number of not random actions was  82
# The reward of the validation episode was  -203.0
# The balanced accuracy was  0.4663276418635772
# Starting episode  7
# The episode duration was  100
# The episode reward was  -58.0
# The number of not random actions was  85
# The reward of the validation episode was  -421.0
# The balanced accuracy was  0.3622172879356694
# Starting episode  8
# The episode duration was  100
# The episode reward was  -64.0
# The number of not random actions was  81
# The reward of the validation episode was  -416.0
# The balanced accuracy was  0.37164767857411374
# Starting episode  9
# The episode duration was  100
# The episode reward was  -24.0
# The number of not random actions was  84
# The reward of the validation episode was  -221.0
# The balanced accuracy was  0.4902027426755386
# Starting episode  10
# The episode duration was  100
# The episode reward was  -26.0
# The number of not random actions was  79
# The reward of the validation episode was  -325.0
# The balanced accuracy was  0.47698514245396373
# Starting episode  11
# The episode duration was  100
# The episode reward was  -68.0
# The number of not random actions was  82
# The reward of the validation episode was  -349.0
# The balanced accuracy was  0.4794258762673443
# Starting episode  12
# The episode duration was  100
# The episode reward was  -23.0
# The number of not random actions was  81
# The reward of the validation episode was  964.0
# The balanced accuracy was  0.5475727266172865
# Starting episode  13
# The episode duration was  100
# The episode reward was  -98.0
# The number of not random actions was  75
# The reward of the validation episode was  1008.0
# The balanced accuracy was  0.5548165585503771
# Starting episode  14
# The episode duration was  100
# The episode reward was  -22.0
# The number of not random actions was  77
# The reward of the validation episode was  1167.0
# The balanced accuracy was  0.5609566430760797
# Starting episode  15
# The episode duration was  100
# The episode reward was  -31.0
# The number of not random actions was  83
# The reward of the validation episode was  1377.0
# The balanced accuracy was  0.5708588125948584
# Starting episode  16
# The episode duration was  100
# The episode reward was  18.0
# The number of not random actions was  79
# The reward of the validation episode was  1714.0
# The balanced accuracy was  0.5666809297038806
# Starting episode  17
# The episode duration was  100
# The episode reward was  15.0
# The number of not random actions was  73
# The reward of the validation episode was  1469.0
# The balanced accuracy was  0.5640994915807686
# Starting episode  18
# The episode duration was  100
# The episode reward was  32.0
# The number of not random actions was  79
# The reward of the validation episode was  1505.0
# The balanced accuracy was  0.5669889965066335
# Starting episode  19
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  81
# The reward of the validation episode was  1712.0
# The balanced accuracy was  0.577207613709029
# Starting episode  20
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  87
# The reward of the validation episode was  1609.0
# The balanced accuracy was  0.5793305112934488
# Starting episode  21
# The episode duration was  100
# The episode reward was  1.0
# The number of not random actions was  77
# The reward of the validation episode was  2051.0
# The balanced accuracy was  0.5818176226679108
# Starting episode  22
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  79
# The reward of the validation episode was  1960.0
# The balanced accuracy was  0.5880271531814713
# Starting episode  23
# The episode duration was  100
# The episode reward was  35.0
# The number of not random actions was  88
# The reward of the validation episode was  2007.0
# The balanced accuracy was  0.574690131391986
# Starting episode  24
# The episode duration was  100
# The episode reward was  35.0
# The number of not random actions was  85
# The reward of the validation episode was  2020.0
# The balanced accuracy was  0.5792583428476685
# Starting episode  25
# The episode duration was  100
# The episode reward was  52.0
# The number of not random actions was  80
# The reward of the validation episode was  1804.0
# The balanced accuracy was  0.5842442543990238
# Starting episode  26
# The episode duration was  100
# The episode reward was  50.0
# The number of not random actions was  78
# The reward of the validation episode was  1772.0
# The balanced accuracy was  0.5867921539267892
# Starting episode  27
# The episode duration was  100
# The episode reward was  2.0
# The number of not random actions was  79
# The reward of the validation episode was  2071.0
# The balanced accuracy was  0.7109344856618199
# Starting episode  28
# The episode duration was  100
# The episode reward was  52.0
# The number of not random actions was  84
# The reward of the validation episode was  1861.0
# The balanced accuracy was  0.5413125570166969
# Starting episode  29
# The episode duration was  100
# The episode reward was  58.0
# The number of not random actions was  79
# The reward of the validation episode was  1990.0
# The balanced accuracy was  0.5792038680407333
# Starting episode  30
# The episode duration was  100
# The episode reward was  81.0
# The number of not random actions was  89
# The reward of the validation episode was  2005.0
# The balanced accuracy was  0.5832393910557331
# Starting episode  31
# The episode duration was  100
# The episode reward was  2.0
# The number of not random actions was  78
# The reward of the validation episode was  1585.0
# The balanced accuracy was  0.5480408106887011
# Starting episode  32
# The episode duration was  100
# The episode reward was  42.0
# The number of not random actions was  78
# The reward of the validation episode was  2079.0
# The balanced accuracy was  0.7089538919843491
# Starting episode  33
# The episode duration was  100
# The episode reward was  55.0
# The number of not random actions was  79
# The reward of the validation episode was  1987.0
# The balanced accuracy was  0.5896087557697852
# Starting episode  34
# The episode duration was  100
# The episode reward was  6.0
# The number of not random actions was  78
# The reward of the validation episode was  2143.0
# The balanced accuracy was  0.5819319095002603
# Starting episode  35
# The episode duration was  100
# The episode reward was  13.0
# The number of not random actions was  79
# The reward of the validation episode was  1938.0
# The balanced accuracy was  0.6107599503291955
# Starting episode  36
# The episode duration was  100
# The episode reward was  37.0
# The number of not random actions was  85
# The reward of the validation episode was  1977.0
# The balanced accuracy was  0.5688135853432909
# Starting episode  37
# The episode duration was  100
# The episode reward was  103.0
# The number of not random actions was  80
# The reward of the validation episode was  2002.0
# The balanced accuracy was  0.5742047889437821
# Starting episode  38
# The episode duration was  100
# The episode reward was  99.0
# The number of not random actions was  82
# The reward of the validation episode was  2029.0
# The balanced accuracy was  0.5721214436049517
# Starting episode  39
# The episode duration was  100
# The episode reward was  23.0
# The number of not random actions was  80
# The reward of the validation episode was  2064.0
# The balanced accuracy was  0.5703985048729541
# Starting episode  40
# The episode duration was  100
# The episode reward was  45.0
# The number of not random actions was  74
# The reward of the validation episode was  2052.0
# The balanced accuracy was  0.579536793182936
# Starting episode  41
# The episode duration was  100
# The episode reward was  51.0
# The number of not random actions was  78
# The reward of the validation episode was  2175.0
# The balanced accuracy was  0.5736389303955277
# Starting episode  42
# The episode duration was  100
# The episode reward was  -56.0
# The number of not random actions was  77
# The reward of the validation episode was  2168.0
# The balanced accuracy was  0.5610518316631253
# Starting episode  43
# The episode duration was  100
# The episode reward was  6.0
# The number of not random actions was  79
# The reward of the validation episode was  2089.0
# The balanced accuracy was  0.5812133388587034
# Starting episode  44
# The episode duration was  100
# The episode reward was  4.0
# The number of not random actions was  77
# The reward of the validation episode was  2095.0
# The balanced accuracy was  0.586481855678272
# Starting episode  45
# The episode duration was  100
# The episode reward was  42.0
# The number of not random actions was  85
# The reward of the validation episode was  2037.0
# The balanced accuracy was  0.5912923009115981
# Starting episode  46
# The episode duration was  100
# The episode reward was  85.0
# The number of not random actions was  78
# The reward of the validation episode was  2035.0
# The balanced accuracy was  0.5827557808808435
# Starting episode  47
# The episode duration was  100
# The episode reward was  79.0
# The number of not random actions was  78
# The reward of the validation episode was  2194.0
# The balanced accuracy was  0.6930655542088406
# Starting episode  48
# The episode duration was  100
# The episode reward was  -31.0
# The number of not random actions was  77
# The reward of the validation episode was  2189.0
# The balanced accuracy was  0.7155856109446352
# Starting episode  49
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  75
# The reward of the validation episode was  2142.0
# The balanced accuracy was  0.718156616975439
# Starting episode  50
# The episode duration was  100
# The episode reward was  59.0
# The number of not random actions was  80
# The reward of the validation episode was  2164.0
# The balanced accuracy was  0.7081568519370327
# Starting episode  51
# The episode duration was  100
# The episode reward was  0.0
# The number of not random actions was  81
# The reward of the validation episode was  2151.0
# The balanced accuracy was  0.715323899133273
# Starting episode  52
# The episode duration was  100
# The episode reward was  32.0
# The number of not random actions was  75
# The reward of the validation episode was  1936.0
# The balanced accuracy was  0.5349525892193118
# Starting episode  53
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  80
# The reward of the validation episode was  2177.0
# The balanced accuracy was  0.7232810976147439
# Starting episode  54
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  85
# The reward of the validation episode was  2198.0
# The balanced accuracy was  0.7189480313772024
# Starting episode  55
# The episode duration was  100
# The episode reward was  15.0
# The number of not random actions was  79
# The reward of the validation episode was  2005.0
# The balanced accuracy was  0.7141265240492675
# Starting episode  56
# The episode duration was  100
# The episode reward was  78.0
# The number of not random actions was  82
# The reward of the validation episode was  2157.0
# The balanced accuracy was  0.7235323809063579
# Starting episode  57
# The episode duration was  100
# The episode reward was  1.0
# The number of not random actions was  74
# The reward of the validation episode was  2250.0
# The balanced accuracy was  0.7162328103816671
# Starting episode  58
# The episode duration was  100
# The episode reward was  86.0
# The number of not random actions was  87
# The reward of the validation episode was  2249.0
# The balanced accuracy was  0.7304623913897716
# Starting episode  59
# The episode duration was  100
# The episode reward was  71.0
# The number of not random actions was  80
# The reward of the validation episode was  2226.0
# The balanced accuracy was  0.7104812004954358
# Starting episode  60
# The episode duration was  100
# The episode reward was  22.0
# The number of not random actions was  73
# The reward of the validation episode was  2210.0
# The balanced accuracy was  0.7175663175161795
# Starting episode  61
# The episode duration was  100
# The episode reward was  73.0
# The number of not random actions was  84
# The reward of the validation episode was  2160.0
# The balanced accuracy was  0.7246431461793686
# Starting episode  62
# The episode duration was  100
# The episode reward was  32.0
# The number of not random actions was  82
# The reward of the validation episode was  2248.0
# The balanced accuracy was  0.7094903513750535
# Starting episode  63
# The episode duration was  100
# The episode reward was  72.0
# The number of not random actions was  87
# The reward of the validation episode was  2198.0
# The balanced accuracy was  0.8669607234285205
# Starting episode  64
# The episode duration was  100
# The episode reward was  45.0
# The number of not random actions was  84
# The reward of the validation episode was  2199.0
# The balanced accuracy was  0.7228582933246027
# Starting episode  65
# The episode duration was  100
# The episode reward was  32.0
# The number of not random actions was  75
# The reward of the validation episode was  2237.0
# The balanced accuracy was  0.704304656180401
# Starting episode  66
# The episode duration was  100
# The episode reward was  68.0
# The number of not random actions was  84
# The reward of the validation episode was  2146.0
# The balanced accuracy was  0.7197341085604867
# Starting episode  67
# The episode duration was  100
# The episode reward was  30.0
# The number of not random actions was  84
# The reward of the validation episode was  2297.0
# The balanced accuracy was  0.8591656047521907
# Starting episode  68
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  80
# The reward of the validation episode was  2360.0
# The balanced accuracy was  0.8605783159295513
# Starting episode  69
# The episode duration was  100
# The episode reward was  -2.0
# The number of not random actions was  84
# The reward of the validation episode was  2303.0
# The balanced accuracy was  0.8654086001606239
# Starting episode  70
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  80
# The reward of the validation episode was  2338.0
# The balanced accuracy was  0.8557767845207856
# Starting episode  71
# The episode duration was  100
# The episode reward was  88.0
# The number of not random actions was  80
# The reward of the validation episode was  2215.0
# The balanced accuracy was  0.8635504126356593
# Starting episode  72
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  85
# The reward of the validation episode was  2301.0
# The balanced accuracy was  0.8698591263434763
# Starting episode  73
# The episode duration was  100
# The episode reward was  69.0
# The number of not random actions was  81
# The reward of the validation episode was  2238.0
# The balanced accuracy was  0.8608791837899339
# Starting episode  74
# The episode duration was  100
# The episode reward was  95.0
# The number of not random actions was  89
# The reward of the validation episode was  2351.0
# The balanced accuracy was  0.8566147021380865
# Starting episode  75
# The episode duration was  100
# The episode reward was  16.0
# The number of not random actions was  80
# The reward of the validation episode was  2354.0
# The balanced accuracy was  0.8603932092888512
# Starting episode  76
# The episode duration was  100
# The episode reward was  43.0
# The number of not random actions was  79
# The reward of the validation episode was  2262.0
# The balanced accuracy was  0.8627654584152461
# Starting episode  77
# The episode duration was  100
# The episode reward was  -23.0
# The number of not random actions was  81
# The reward of the validation episode was  2229.0
# The balanced accuracy was  0.864954211099078
# Starting episode  78
# The episode duration was  100
# The episode reward was  44.0
# The number of not random actions was  78
# The reward of the validation episode was  2288.0
# The balanced accuracy was  0.8686771241547627
# Starting episode  79
# The episode duration was  100
# The episode reward was  105.0
# The number of not random actions was  76
# The reward of the validation episode was  2297.0
# The balanced accuracy was  0.8587307478617404
# Starting episode  80
# The episode duration was  100
# The episode reward was  -11.0
# The number of not random actions was  79
# The reward of the validation episode was  2202.0
# The balanced accuracy was  0.8629126639315791
# Starting episode  81
# The episode duration was  100
# The episode reward was  48.0
# The number of not random actions was  84
# The reward of the validation episode was  2276.0
# The balanced accuracy was  0.8632223999080921
# Starting episode  82
# The episode duration was  100
# The episode reward was  16.0
# The number of not random actions was  73
# The reward of the validation episode was  2289.0
# The balanced accuracy was  0.8340489439373567
# Starting episode  83
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  71
# The reward of the validation episode was  2255.0
# The balanced accuracy was  0.8646479691188962
# Starting episode  84
# The episode duration was  100
# The episode reward was  87.0
# The number of not random actions was  80
# The reward of the validation episode was  2281.0
# The balanced accuracy was  0.8641957777105548
# Starting episode  85
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  82
# The reward of the validation episode was  2247.0
# The balanced accuracy was  0.8553906361955688
# Starting episode  86
# The episode duration was  100
# The episode reward was  -28.0
# The number of not random actions was  81
# The reward of the validation episode was  2284.0
# The balanced accuracy was  0.8511414318831629
# Starting episode  87
# The episode duration was  100
# The episode reward was  75.0
# The number of not random actions was  84
# The reward of the validation episode was  2252.0
# The balanced accuracy was  0.8510760274387895
# Starting episode  88
# The episode duration was  100
# The episode reward was  72.0
# The number of not random actions was  85
# The reward of the validation episode was  2197.0
# The balanced accuracy was  0.8670952077114383
# Starting episode  89
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  76
# The reward of the validation episode was  2360.0
# The balanced accuracy was  0.8503785622651454
# Starting episode  90
# The episode duration was  100
# The episode reward was  14.0
# The number of not random actions was  76
# The reward of the validation episode was  2381.0
# The balanced accuracy was  0.855006892572893
# Starting episode  91
# The episode duration was  100
# The episode reward was  87.0
# The number of not random actions was  78
# The reward of the validation episode was  2124.0
# The balanced accuracy was  0.8489692458535395
# Starting episode  92
# The episode duration was  100
# The episode reward was  27.0
# The number of not random actions was  80
# The reward of the validation episode was  2129.0
# The balanced accuracy was  0.7220847323391305
# Starting episode  93
# The episode duration was  100
# The episode reward was  101.0
# The number of not random actions was  77
# The reward of the validation episode was  2229.0
# The balanced accuracy was  0.8575244670921528
# Starting episode  94
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  82
# The reward of the validation episode was  2371.0
# The balanced accuracy was  0.8198714216411153
# Starting episode  95
# The episode duration was  100
# The episode reward was  32.0
# The number of not random actions was  80
# The reward of the validation episode was  2293.0
# The balanced accuracy was  0.8414364597309404
# Starting episode  96
# The episode duration was  100
# The episode reward was  53.0
# The number of not random actions was  81
# The reward of the validation episode was  2234.0
# The balanced accuracy was  0.7510033792566011
# Starting episode  97
# The episode duration was  100
# The episode reward was  129.0
# The number of not random actions was  87
# The reward of the validation episode was  2362.0
# The balanced accuracy was  0.863448137159441
# Starting episode  98
# The episode duration was  100
# The episode reward was  35.0
# The number of not random actions was  81
# The reward of the validation episode was  2276.0
# The balanced accuracy was  0.7071382348172854
# Starting episode  99
# The episode duration was  100
# The episode reward was  49.0
# The number of not random actions was  85
# The reward of the validation episode was  2204.0
# The balanced accuracy was  0.7245460843851577
# Starting episode  100
# The episode duration was  100
# The episode reward was  114.0
# The number of not random actions was  87
# The reward of the validation episode was  2163.0
# The balanced accuracy was  0.7351240261546003
# Starting episode  101
# The episode duration was  100
# The episode reward was  39.0
# The number of not random actions was  80
# The reward of the validation episode was  2211.0
# The balanced accuracy was  0.7205848529983706
# Starting episode  102
# The episode duration was  100
# The episode reward was  80.0
# The number of not random actions was  81
# The reward of the validation episode was  2209.0
# The balanced accuracy was  0.7303585223326062
# Starting episode  103
# The episode duration was  100
# The episode reward was  107.0
# The number of not random actions was  89
# The reward of the validation episode was  2345.0
# The balanced accuracy was  0.863020734309675
# Starting episode  104
# The episode duration was  100
# The episode reward was  108.0
# The number of not random actions was  85
# The reward of the validation episode was  2311.0
# The balanced accuracy was  0.8667758605149171
# Starting episode  105
# The episode duration was  100
# The episode reward was  78.0
# The number of not random actions was  79
# The reward of the validation episode was  2220.0
# The balanced accuracy was  0.8558300808403926
# Starting episode  106
# The episode duration was  100
# The episode reward was  111.0
# The number of not random actions was  85
# The reward of the validation episode was  2341.0
# The balanced accuracy was  0.8672764689313448
# Starting episode  107
# The episode duration was  100
# The episode reward was  76.0
# The number of not random actions was  82
# The reward of the validation episode was  2308.0
# The balanced accuracy was  0.8620648131002809
# Starting episode  108
# The episode duration was  100
# The episode reward was  56.0
# The number of not random actions was  86
# The reward of the validation episode was  2328.0
# The balanced accuracy was  0.8541563715779754
# Starting episode  109
# The episode duration was  100
# The episode reward was  103.0
# The number of not random actions was  79
# The reward of the validation episode was  2298.0
# The balanced accuracy was  0.8623213819842032
# Starting episode  110
# The episode duration was  100
# The episode reward was  18.0
# The number of not random actions was  75
# The reward of the validation episode was  2344.0
# The balanced accuracy was  0.8532918548618922
# Starting episode  111
# The episode duration was  100
# The episode reward was  36.0
# The number of not random actions was  84
# The reward of the validation episode was  2474.0
# The balanced accuracy was  0.8615925568007076
# Starting episode  112
# The episode duration was  100
# The episode reward was  -12.0
# The number of not random actions was  84
# The reward of the validation episode was  2299.0
# The balanced accuracy was  0.8180901969377495
# Starting episode  113
# The episode duration was  100
# The episode reward was  10.0
# The number of not random actions was  83
# The reward of the validation episode was  2248.0
# The balanced accuracy was  0.8531799504342205
# Starting episode  114
# The episode duration was  100
# The episode reward was  -8.0
# The number of not random actions was  86
# The reward of the validation episode was  2347.0
# The balanced accuracy was  0.8663967231483578
# Starting episode  115
# The episode duration was  100
# The episode reward was  60.0
# The number of not random actions was  85
# The reward of the validation episode was  2412.0
# The balanced accuracy was  0.8593948104697685
# Starting episode  116
# The episode duration was  100
# The episode reward was  100.0
# The number of not random actions was  87
# The reward of the validation episode was  2536.0
# The balanced accuracy was  0.847561418442081
# Starting episode  117
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  78
# The reward of the validation episode was  2513.0
# The balanced accuracy was  0.856300452107674
# Starting episode  118
# The episode duration was  100
# The episode reward was  5.0
# The number of not random actions was  88
# The reward of the validation episode was  2297.0
# The balanced accuracy was  0.8580715167351827
# Starting episode  119
# The episode duration was  100
# The episode reward was  86.0
# The number of not random actions was  84
# The reward of the validation episode was  2376.0
# The balanced accuracy was  0.86845368780896
# Starting episode  120
# The episode duration was  100
# The episode reward was  46.0
# The number of not random actions was  80
# The reward of the validation episode was  2328.0
# The balanced accuracy was  0.8660323423382872
# Starting episode  121
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  84
# The reward of the validation episode was  2420.0
# The balanced accuracy was  0.862850860410605
# Starting episode  122
# The episode duration was  100
# The episode reward was  30.0
# The number of not random actions was  83
# The reward of the validation episode was  2406.0
# The balanced accuracy was  0.8694756710457083
# Starting episode  123
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  83
# The reward of the validation episode was  2321.0
# The balanced accuracy was  0.8401763860018153
# Starting episode  124
# The episode duration was  100
# The episode reward was  12.0
# The number of not random actions was  84
# The reward of the validation episode was  2283.0
# The balanced accuracy was  0.8534351810512836
# Starting episode  125
# The episode duration was  100
# The episode reward was  11.0
# The number of not random actions was  78
# The reward of the validation episode was  2255.0
# The balanced accuracy was  0.8632688743612881
# Starting episode  126
# The episode duration was  100
# The episode reward was  79.0
# The number of not random actions was  82
# The reward of the validation episode was  2296.0
# The balanced accuracy was  0.8594307946715134
# Starting episode  127
# The episode duration was  100
# The episode reward was  94.0
# The number of not random actions was  83
# The reward of the validation episode was  2233.0
# The balanced accuracy was  0.8577475449851335
# Starting episode  128
# The episode duration was  100
# The episode reward was  -19.0
# The number of not random actions was  76
# The reward of the validation episode was  1679.0
# The balanced accuracy was  0.6316097917045443
# Starting episode  129
# The episode duration was  100
# The episode reward was  95.0
# The number of not random actions was  79
# The reward of the validation episode was  2246.0
# The balanced accuracy was  0.8567535971203961
# Starting episode  130
# The episode duration was  100
# The episode reward was  43.0
# The number of not random actions was  80
# The reward of the validation episode was  2214.0
# The balanced accuracy was  0.7754856470306768
# Starting episode  131
# The episode duration was  100
# The episode reward was  48.0
# The number of not random actions was  85
# The reward of the validation episode was  2325.0
# The balanced accuracy was  0.8492471824342139
# Starting episode  132
# The episode duration was  100
# The episode reward was  80.0
# The number of not random actions was  90
# The reward of the validation episode was  2245.0
# The balanced accuracy was  0.8663537248578821
# Starting episode  133
# The episode duration was  100
# The episode reward was  73.0
# The number of not random actions was  79
# The reward of the validation episode was  2226.0
# The balanced accuracy was  0.861035054837313
# Starting episode  134
# The episode duration was  100
# The episode reward was  52.0
# The number of not random actions was  84
# The reward of the validation episode was  2279.0
# The balanced accuracy was  0.8636934256495946
# Starting episode  135
# The episode duration was  100
# The episode reward was  9.0
# The number of not random actions was  80
# The reward of the validation episode was  2194.0
# The balanced accuracy was  0.8528513099966324
# Starting episode  136
# The episode duration was  100
# The episode reward was  46.0
# The number of not random actions was  78
# The reward of the validation episode was  2270.0
# The balanced accuracy was  0.8634470624691076
# Starting episode  137
# The episode duration was  100
# The episode reward was  115.0
# The number of not random actions was  83
# The reward of the validation episode was  2252.0
# The balanced accuracy was  0.8680241094824586
# Starting episode  138
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  79
# The reward of the validation episode was  2248.0
# The balanced accuracy was  0.8585281443730184
# Starting episode  139
# The episode duration was  100
# The episode reward was  97.0
# The number of not random actions was  78
# The reward of the validation episode was  2220.0
# The balanced accuracy was  0.8548103284834426
# Starting episode  140
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  73
# The reward of the validation episode was  2289.0
# The balanced accuracy was  0.8432800435719822
# Starting episode  141
# The episode duration was  100
# The episode reward was  20.0
# The number of not random actions was  87
# The reward of the validation episode was  2208.0
# The balanced accuracy was  0.8642770579995617
# Starting episode  142
# The episode duration was  100
# The episode reward was  71.0
# The number of not random actions was  83
# The reward of the validation episode was  2163.0
# The balanced accuracy was  0.8406972065329554
# Starting episode  143
# The episode duration was  100
# The episode reward was  -13.0
# The number of not random actions was  77
# The reward of the validation episode was  2241.0
# The balanced accuracy was  0.8624893388584853
# Starting episode  144
# The episode duration was  100
# The episode reward was  94.0
# The number of not random actions was  81
# The reward of the validation episode was  2270.0
# The balanced accuracy was  0.8579653335089145
# Starting episode  145
# The episode duration was  100
# The episode reward was  103.0
# The number of not random actions was  79
# The reward of the validation episode was  2247.0
# The balanced accuracy was  0.8647671505322702
# Starting episode  146
# The episode duration was  100
# The episode reward was  136.0
# The number of not random actions was  85
# The reward of the validation episode was  2216.0
# The balanced accuracy was  0.8538173852832903
# Starting episode  147
# The episode duration was  100
# The episode reward was  47.0
# The number of not random actions was  89
# The reward of the validation episode was  2319.0
# The balanced accuracy was  0.8508714955540618
# Starting episode  148
# The episode duration was  100
# The episode reward was  39.0
# The number of not random actions was  80
# The reward of the validation episode was  2178.0
# The balanced accuracy was  0.8492018475003917
# Starting episode  149
# The episode duration was  100
# The episode reward was  2.0
# The number of not random actions was  84
# The reward of the validation episode was  2191.0
# The balanced accuracy was  0.8629475364395047
# The scores for best validation BAcc are:
#               precision    recall  f1-score   support
#
#          0.0      0.883     0.815     0.848        65
#          1.0      0.864     0.922     0.892       103
#          2.0      0.806     0.832     0.819       220
#          3.0      0.913     0.913     0.913        23
#          4.0      0.712     0.709     0.710       223
#          5.0      0.939     0.934     0.936      1341
#          6.0      0.964     0.964     0.964        28
#
#     accuracy                          0.893      2003
#    macro avg      0.869     0.870     0.869      2003
# weighted avg      0.894     0.893     0.893      2003
#
# [[  53    1   10    0    1    0    0]
#  [   1   95    4    0    1    2    0]
#  [   5    5  183    0    9   18    0]
#  [   0    0    0   21    0    2    0]
#  [   0    1    6    0  158   58    0]
#  [   1    8   24    2   53 1252    1]
#  [   0    0    0    0    0    1   27]]
# The best BAcc was  0.8698591263434763
# The scores for best validation Reward are:
#               precision    recall  f1-score   support
#
#          0.0      0.881     0.800     0.839        65
#          1.0      0.857     0.932     0.893       103
#          2.0      0.793     0.800     0.796       220
#          3.0      1.000     0.739     0.850        23
#          4.0      0.688     0.771     0.727       223
#          5.0      0.944     0.926     0.935      1341
#          6.0      0.964     0.964     0.964        28
#
#     accuracy                          0.890      2003
#    macro avg      0.875     0.848     0.858      2003
# weighted avg      0.894     0.890     0.891      2003
#
# [[  52    1   10    0    2    0    0]
#  [   1   96    3    0    1    2    0]
#  [   5    7  176    0   12   20    0]
#  [   0    0    0   17    0    6    0]
#  [   0    1    6    0  172   44    0]
#  [   1    7   27    0   63 1242    1]
#  [   0    0    0    0    0    1   27]]
# The best reward was  2536.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\IPython\core\interactiveshell.py:3675: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
