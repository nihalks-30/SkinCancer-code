# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import os.path
import sys
import numpy as np
import math
import sklearn.metrics as metrics
from tqdm import tqdm
from gym import Env, spaces
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split


from tensorflow.python.keras import backend
from tensorflow.keras.backend import clear_session


import time
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="google.protobuf")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.0 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import csv

import tensorflow as tf
import tensorflow.compat.v1 as tf1
import tensorflow.keras as K

from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = str(0)


from sklearn.feature_extraction.text import CountVectorizer

# %%
def read_and_decode(dataset, batch_size, is_training, data_size,n_patients):
    if is_training:
        dataset = dataset.shuffle(buffer_size=data_size, reshuffle_each_iteration=True)
        dataset = dataset.batch(batch_size, drop_remainder=False)
        dataset = dataset.repeat(None)
    else:
        dataset = dataset.prefetch(buffer_size=data_size // batch_size)
        dataset = dataset.batch(batch_size, drop_remainder=False)
        dataset = dataset.repeat(None)
    return dataset

# %%
def create_q_model(n_classes, n_words, n_actions):
    
    # The only change is on this line:
    inputs = K.layers.Input(shape=(n_classes,))

    feat = K.layers.Lambda(lambda x: x[:, 0:n_classes - n_words])(inputs)
    
    emb = K.layers.Dropout(0.05)(feat)
    
    prob = K.layers.Lambda(lambda x: x[:, n_classes - n_words:n_classes])(inputs)
    
    emb = K.layers.Dense(256, activation="relu")(emb)
    
    emb = K.layers.Dropout(0.05)(emb)
    
    emb = K.layers.Concatenate(axis=1)([emb, prob])
    
    action = K.layers.Dense(n_actions, activation=None)(emb)
    
    return K.Model(inputs=inputs, outputs=action)

# %%
def initialize_clinical_practice(clinical_cases_feat,clinical_cases_labels,dataset_size,n_classes,is_training,n_patients,set_distribution):

    if is_training:
        _, counts = np.unique(clinical_cases_labels, return_counts=True)

        akiec = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 0), axis=0))
        akiec_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 0), axis=0))

        bcc = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 1), axis=0))
        bcc_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 1), axis=0))

        bkl = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 2), axis=0))
        bkl_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 2), axis=0))

        df = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 3), axis=0))
        df_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 3), axis=0))

        mel = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 4), axis=0))
        mel_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 4), axis=0))

        nv = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 5), axis=0))
        nv_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 5), axis=0))

        vasc = np.squeeze(np.take(clinical_cases_feat, np.where(clinical_cases_labels == 6), axis=0))
        vasc_labels = np.squeeze(np.take(clinical_cases_labels, np.where(clinical_cases_labels == 6), axis=0))

        akiec_set = tf.data.Dataset.from_tensor_slices((akiec, akiec_labels)).shuffle(buffer_size=counts[0],
                                                                                      reshuffle_each_iteration=True).repeat()
        bcc_set = tf.data.Dataset.from_tensor_slices((bcc, bcc_labels)).shuffle(buffer_size=counts[1],
                                                                                reshuffle_each_iteration=True).repeat()
        bkl_set = tf.data.Dataset.from_tensor_slices((bkl, bkl_labels)).shuffle(buffer_size=counts[2],
                                                                                reshuffle_each_iteration=True).repeat()
        df_set = tf.data.Dataset.from_tensor_slices((df, df_labels)).shuffle(buffer_size=counts[3],
                                                                             reshuffle_each_iteration=True).repeat()
        mel_set = tf.data.Dataset.from_tensor_slices((mel, mel_labels)).shuffle(buffer_size=counts[4],
                                                                                reshuffle_each_iteration=True).repeat()
        nv_set = tf.data.Dataset.from_tensor_slices((nv, nv_labels)).shuffle(buffer_size=counts[5],
                                                                             reshuffle_each_iteration=True).repeat()
        vasc_set = tf.data.Dataset.from_tensor_slices((vasc, vasc_labels)).shuffle(buffer_size=counts[6],
                                                                                   reshuffle_each_iteration=True).repeat()

        dataset_train = tf.data.Dataset.sample_from_datasets([akiec_set, bcc_set, bkl_set, df_set, mel_set, nv_set, vasc_set], weights=set_distribution)
        dataset_train = dataset_train.batch(1)

    else:
        dataset_train = tf.data.Dataset.from_tensor_slices((clinical_cases_feat,clinical_cases_labels))

        dataset_train = read_and_decode(dataset_train, 1, is_training, dataset_size,n_patients)

    patients = iter(dataset_train)

    return patients

# %%
 def get_next_patient(patients):
        patient_scores,patient_diagnostics = patients.get_next()
    
        return np.squeeze(patient_scores),patient_diagnostics.numpy()[0]

# %%
class Dermatologist(Env):

    def __init__(self,patients,n_classes,vocab):
        # Actions we can take, either skin lesion classes or don't know
        self.action_space = spaces.Discrete(len(vocab))
        # Observation space - softmax + features after GAP
        self.observation_space = spaces.Box(-1*math.inf*np.ones((n_classes,)),math.inf*np.ones((n_classes,)))
        # Initialize state
        n_state,n_gt = get_next_patient(patients)
        self.state = n_state
        self.revised_state = self.state
        self.gt = n_gt
        # Set shower length
        self.number_of_patients = 0

    def step(self,patients,n_patients,vocab,action):
        ### UNKN_reward = -1
        reward_table = np.array([[2,-2,-3,	-3,	-2,	-3,	-3,	-1],
                                 [-2,3,	-4,	-4,	-2,	-4,	-4,	-1],
                                 [-2,-2, 1,	-2,	-3,	-2,	-2,	-1],
                                 [-2,-2,-2,	1,-3,	-2,	-2,	-1],
                                 [-4, -3, -12, -5, 10, -12, -5, -1],
                                 [-2,-2,-2,	-2,	-3,	1,	-2,	-1],
                                 [-2,-2,-2,	-2,	-3,	-2,	1,	-1],
                                 ],np.float32)

        ### UNKN_reward = 0
        # reward_table = np.array([[2, -2, -3, -3, -2, -3, -3, 0],
        #                          [-2, 3, -4, -4, -2, -4, -4, 0],
        #                          [-2, -2, 1, -2, -3, -2, -2, 0],
        #                          [-2, -2, -2, 1, -3, -2, -2, 0],
        #                          [-4, -3, -5, -5, 5, -5, -5, 0],
        #                          [-2, -2, -2, -2, -3, 1, -2, 0],
        #                          [-2, -2, -2, -2, -3, -2, 1, 0],
        #                          ], np.float32)

        ### UNKN_reward = 0.5
        # reward_table = np.array([[2, -2, -3, -3, -2, -3, -3, 0.5],
        #                          [-2, 3, -4, -4, -2, -4, -4, 0.5],
        #                          [-2, -2, 1, -2, -3, -2, -2, 0.5],
        #                          [-2, -2, -2, 1, -3, -2, -2, 0.5],
        #                          [-4, -3, -5, -5, 5, -5, -5, 0.5],
        #                          [-2, -2, -2, -2, -3, 1, -2, 0.5],
        #                          [-2, -2, -2, -2, -3, -2, 1, 0.5],
        #                          ], np.float32)

        
        self.revised_state = tf.one_hot(action,len(vocab))

        reward = reward_table[self.gt,action]

        n_state, n_gt = get_next_patient(patients)

        old_gt = self.gt

        self.state = n_state
        self.gt = n_gt

        self.number_of_patients += 1

        # Check if checking patients is done
        if self.number_of_patients >= n_patients:# or old_gt != action:
            done = 1
        else:
            done = 0

            #reward += 1000

        return self.revised_state, self.state, reward,done,old_gt

    def reset(self,clinical_cases_feat,clinical_cases_labels,n_classes,dataset_size,vocab,is_training,n_patients,sample_distribution):
        # Reset clinical practice
        patients = initialize_clinical_practice(clinical_cases_feat,clinical_cases_labels, dataset_size,n_classes,is_training,n_patients,sample_distribution)
        n_state, n_gt = get_next_patient(patients)
        self.state = n_state
        self.revised_state = self.state
        self.gt = n_gt
        # Reset new practice
        self.number_of_patients = 0

        return self.state,patients

# %%
def main(_):
    gamma = 0.99  # Discount factor for past rewards
    epsilon = 0.2  # Epsilon greedy parameter
    epsilon_min = 0.1  # Minimum epsilon greedy parameter
    epsilon_max = 0.2  # Maximum epsilon greedy parameter
    epsilon_interval = (epsilon_max - epsilon_min)  # Rate at which to reduce chance of random action being taken

    #### Import Datasets ####
    tf1.enable_eager_execution()

    database = pd.read_csv('data/vectorDB.csv')

    print(database)

    database.head()

    labels = np.asarray(database['dx'])

    print(labels)

    labels[labels == 'scc'] = 'akiec'

    le = preprocessing.LabelEncoder()

    le.fit(labels)

    vocab = le.classes_

    n_words = len(vocab)

    if Flags.use_unknown:
        vocab = np.append(vocab,'unkn')

    features1 = np.load("data/nmed_rn34_ham10k_vectors.npy")

    features2 = pd.read_csv("data/vectorDB.csv")

    features2.pop('dx')

    features2 = np.asarray(features2, dtype='float32')

    features = np.concatenate([features1,features2],axis=1)
    

    _, counts = np.unique(labels, return_counts=True)

    print(counts)

    counts = counts/np.sum(counts)
        

    labels_cat = le.transform(labels)

    print(labels_cat.dtype)

    train_feat, val_feat, train_labels, val_labels = train_test_split(features, labels_cat, test_size=0.2,
                                                                      random_state=111,stratify = labels_cat)


    _, count_train = np.unique(val_labels, return_counts=True)

    print(count_train)

    patients = initialize_clinical_practice(train_feat,train_labels,train_labels.shape[0],True,n_words,Flags.n_patients,counts)

    derm = Dermatologist(patients,n_words,vocab)

    q_network = create_q_model(derm.state.shape[0],n_words,Flags.n_actions)

    q_network.summary()

    target_network = create_q_model(derm.state.shape[0],n_words,Flags.n_actions)

    optimizer = K.optimizers.Adam(learning_rate=0.025, clipnorm=1.0)


    # Experience replay buffers
    action_history = []
    state_history = []
    state_next_history = []
    rewards_history = []
    done_history = []
    episode_reward_history = []
    episode_val_reward_history = []
    validation_bacc_history = []
    mel_history = []
    unk_history = []
    cnn_history = []
    best_bacc = 0
    best_reward = -1*math.inf
    iter_count = 0
    # Number of frames to take random action and observe output
    epsilon_random_frames = 20
    # Number of frames for exploration
    epsilon_greedy_frames = 100000.0
    # Maximum replay length
    max_memory_length = 10000
    # Train the model after 4 actions
    update_after_actions = 10
    # How often to update the target network
    update_target_network = train_feat.shape[0]
    # Using huber loss for stability
    loss_function = K.losses.Huber()

    for episode in range(Flags.n_episodes):
        i = 1
        print('Starting episode ',episode)

        done = False
        episode_score = 0

        episode_val_score = 0

        state = derm.state
        #state = np.concatenate([derm.state, [0]])
        n_not_random = 0
        while not done:
            try:
                iter_count += 1

                # Use epsilon-greedy for exploration
                if iter_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
                    action = derm.action_space.sample()
                else:
                    state_tensor = tf.convert_to_tensor(state)
                    state_tensor = tf.expand_dims(state_tensor, 0)
                    action_probs = q_network(state_tensor, training=False)
                    # Take best action
                    action = tf.argmax(action_probs[0]).numpy()

                    n_not_random += 1

            

                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                revised_state,n_state,reward,done,_ = derm.step(patients,Flags.n_patients,vocab,action)

                episode_score += reward

                # Save actions and states in replay buffer
                action_history.append(action)
                state_history.append(state)
                state_next_history.append(n_state)
                done_history.append(done)
                rewards_history.append(reward)
                state = n_state

                i += 1
                # Update every fourth frame
                # Update every fourth frame
                if iter_count % update_after_actions == 0 and len(done_history) > 100:
                    # Get indices of samples for replay buffers
                    indices = np.random.choice(range(len(done_history)), size=100)

                    # Using list comprehension to sample from replay buffer
                    state_sample = np.array([state_history[i] for i in indices])
                    state_next_sample = np.array([state_next_history[i] for i in indices])
                    rewards_sample = np.array([rewards_history[i] for i in indices], dtype=np.float32)
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor([float(done_history[i]) for i in indices])

                    # ---------------------------------------------------------
                    # [START] DOUBLE DQN LOGIC (DDQN)
                    # ---------------------------------------------------------
                    
                    # 1. Action SELECTION: Use the MAIN network to pick the best action for the next state
                    next_q_values_main = q_network.predict(state_next_sample, verbose=0)
                    best_next_actions = tf.argmax(next_q_values_main, axis=1)

                    # 2. Action EVALUATION: Use the TARGET network to calculate the value of those actions
                    next_q_values_target = target_network.predict(state_next_sample, verbose=0)
                    
                    # We need to gather the Q-values from the target network corresponding 
                    # specifically to the actions chosen by the main network.
                    # We create indices [[0, action_0], [1, action_1], ...]
                    batch_indices = tf.range(tf.shape(best_next_actions)[0], dtype=tf.int64)
                    action_indices = tf.stack([batch_indices, best_next_actions], axis=1)
                    
                    # Extract the Q-values for the chosen actions
                    future_rewards = tf.gather_nd(next_q_values_target, action_indices)

                    # 3. Calculate the Target Q-Value
                    # Q_target = r + gamma * Q_target(s', argmax Q_main(s', a'))
                    updated_q_values = rewards_sample + gamma * future_rewards
                    
                    # ---------------------------------------------------------
                    # [END] DOUBLE DQN LOGIC
                    # ---------------------------------------------------------

                    # If final frame set the last value to -1 (Terminal state handling)
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values
                    masks = tf.one_hot(action_sample, len(vocab))

                    with tf.GradientTape() as tape:
                        # Train the model on the states and updated Q-values
                        q_values = q_network(state_sample, training=True)

                        # Apply the masks to the Q-values to get the Q-value for action taken
                        q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                        # Calculate loss between new Q-value and old Q-value
                        loss = loss_function(updated_q_values, q_action)

                    # Backpropagation
                    grads = tape.gradient(loss, q_network.trainable_variables)
                    optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

                if iter_count % update_target_network == 0:
                    # update the the target network with new weights
                    target_network.set_weights(q_network.get_weights())

                # Limit the state and reward history
                if len(rewards_history) > max_memory_length:
                    del rewards_history[:1]
                    del state_history[:1]
                    del state_next_history[:1]
                    del action_history[:1]
                    del done_history[:1]


            except tf.python.framework.errors_impl.OutOfRangeError:
                done = True
                break

        print('The episode duration was ',i-1)
        print('The episode reward was ',episode_score)
        print('The number of not random actions was ', n_not_random)
        # Update running reward to check condition for solving
        episode_reward_history.append(episode_score)

        ## Validation Phase ##
        state,patients_val = derm.reset(val_feat,val_labels, val_labels.shape[0], n_words, vocab,False,Flags.n_patients,counts)

        done = False

        error = np.array([])
        CNN_error = np.array([])
        true_label = np.array([])

        mel_count = 0

        unk_count = 0

        while not done:
            try:
                true_label = np.append(true_label, derm.gt)

                state_tensor = tf.convert_to_tensor(state)
                state_tensor = tf.expand_dims(state_tensor, 0)
                action_probs = q_network(state_tensor, training=False)
                # Take best action
                action = tf.argmax(action_probs[0]).numpy()

                error = np.append(error, action)

                if vocab[action] == 'mel':
                    mel_count += 1
                elif vocab[action] == 'unkn':
                    unk_count += 1

                _, state, reward, done,_ = derm.step(patients_val, val_labels.shape[0], vocab, action)


                episode_val_score += reward

            except tf.python.framework.errors_impl.OutOfRangeError:
                done = True
                break

        print('The reward of the validation episode was ', episode_val_score)
        print('The balanced accuracy was ', metrics.balanced_accuracy_score(true_label, error))
        episode_val_reward_history.append(episode_val_score)
        validation_bacc_history.append(metrics.balanced_accuracy_score(true_label, error))
        mel_history.append(mel_count)
        unk_history.append(unk_count)

        if best_bacc < metrics.balanced_accuracy_score(true_label, error):
            history_report_bacc = metrics.classification_report(true_label,error,digits=3, zero_division=0)
            history_cov_bacc = metrics.confusion_matrix(true_label,error)
            best_bacc = metrics.balanced_accuracy_score(true_label, error)
            q_network.save_weights('models/best_q_network_diagnosis_bacc.weights.h5')

        if best_reward < episode_val_score:
            history_cov_reward = metrics.confusion_matrix(true_label, error)
            history_report_reward = metrics.classification_report(true_label,error,digits=3, zero_division=0)
            best_reward = episode_val_score
            q_network.save_weights('models/best_q_network_diagnosis_reward.weights.h5')

        ##Return to train
        _,patients = derm.reset(train_feat,train_labels, train_labels.shape[0], n_words, vocab,True,Flags.n_patients,counts)

    q_network.save_weights('models/q_network_diagnosis_final.weights.h5')

    print('The scores for best validation BAcc are:')
    print(history_report_bacc)
    print(history_cov_bacc)
    print('The best BAcc was ',best_bacc)

    print('The scores for best validation Reward are:')
    print(history_report_reward)
    print(history_cov_reward)
    print('The best reward was ', best_reward)

    plt.figure(1)
    plt.plot(episode_reward_history)
    plt.xlabel('Episodes')
    plt.ylabel('Reward Per Episode - Train')
    plt.show()

    plt.figure(2)
    plt.plot(episode_val_reward_history)
    plt.xlabel('Episodes')
    plt.ylabel('Reward Per Episode - Val')
    plt.show()

    plt.figure(3)
    plt.plot(validation_bacc_history)
    plt.xlabel('Episodes')
    plt.ylabel('RL BAcc')
    plt.show()

    plt.figure(4)
    plt.plot(mel_history)
    plt.xlabel('Episodes')
    plt.ylabel('Number Melanoma Decisions')
    plt.show()

    plt.figure(5)
    plt.plot(unk_history)
    plt.xlabel('Episodes')
    plt.ylabel('Number of Unknown Decisions')
    plt.show()

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--n_patients',
        type=int,
        default= 100,
        help='Number of patients per episode.'
    )
    parser.add_argument(
        '--n_episodes',
        type=int,
        default= 150,
        help='Number of episodes to play'
    )
    parser.add_argument(
        '--use_unknown',
        type=bool,
        default=False,
        help='Whether to use unknown action or not distribution'
    )
    parser.add_argument(
        '--n_actions',
        type=int,
        default= 7,
        help='Number of episodes to play'
    )
    Flags, unparsed = parser.parse_known_args()
    tf1.app.run(main=main)
# Out:
# WARNING:tensorflow:From C:\Users\nihal\AppData\Local\Temp\ipykernel_32968\3255693980.py:365: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From C:\Users\nihal\AppData\Local\Temp\ipykernel_32968\3255693980.py:9: The name tf.enable_eager_execution is deprecated. Please use tf.compat.v1.enable_eager_execution instead.
# W1130 19:32:19.251591 13052 module_wrapper.py:149] From C:\Users\nihal\AppData\Local\Temp\ipykernel_32968\3255693980.py:9: The name tf.enable_eager_execution is deprecated. Please use tf.compat.v1.enable_eager_execution instead.
#               akiec       bcc       bkl            df       mel        nv  \
# 0      1.239820e-04  0.001757  0.071755  2.613447e-02  0.004628  0.895575
# 1      1.564469e-03  0.000353  0.582653  1.401107e-02  0.000817  0.400582
# 2      7.310000e-07  0.000002  0.005028  5.290000e-07  0.002840  0.992129
# 3      3.012000e-03  0.027224  0.293466  3.917728e-02  0.062816  0.561710
# 4      1.044428e-03  0.007633  0.776036  3.400000e-05  0.197736  0.017514
# ...             ...       ...       ...           ...       ...       ...
# 10010  2.074046e-03  0.001095  0.002900  4.630000e-05  0.991719  0.000645
# 10011  9.210000e-06  0.000346  0.001581  4.070000e-05  0.308520  0.689383
# 10012  5.650000e-05  0.001307  0.977360  3.800000e-05  0.000746  0.020455
# 10013  3.850000e-06  0.000040  0.004911  2.747410e-04  0.214675  0.780093
# 10014  2.450000e-05  0.000041  0.013609  5.980000e-05  0.091868  0.894389
#
#                vasc   dx
# 0      2.630000e-05   nv
# 1      1.920000e-05   nv
# 2      4.690000e-07   nv
# 3      1.259401e-02   nv
# 4      1.840000e-06  mel
# ...             ...  ...
# 10010  1.519908e-03  mel
# 10011  1.203480e-04  mel
# 10012  3.710000e-05  bkl
# 10013  2.210000e-06   nv
# 10014  8.780000e-06   nv
#
# [10015 rows x 8 columns]
# ['nv' 'nv' 'nv' ... 'bkl' 'nv' 'nv']
# [ 327  514 1099  115 1113 6705  142]
# int64
# [  65  103  220   23  223 1341   28]
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 519)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 512)       │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 7)         │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 263)       │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 7)         │      1,848 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 133,176 (520.22 KB)
#  Trainable params: 133,176 (520.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting episode  0
# The episode duration was  100
# The episode reward was  -210.0
# The number of not random actions was  70
# The reward of the validation episode was  -4575.0
# The balanced accuracy was  0.13878007058319372
# Starting episode  1
# The episode duration was  100
# The episode reward was  -168.0
# The number of not random actions was  84
# The reward of the validation episode was  -2484.0
# The balanced accuracy was  0.14285714285714285
# Starting episode  2
# The episode duration was  100
# The episode reward was  -142.0
# The number of not random actions was  84
# The reward of the validation episode was  -2484.0
# The balanced accuracy was  0.14285714285714285
# Starting episode  3
# The episode duration was  100
# The episode reward was  -99.0
# The number of not random actions was  79
# The reward of the validation episode was  -2484.0
# The balanced accuracy was  0.14285714285714285
# Starting episode  4
# The episode duration was  100
# The episode reward was  -104.0
# The number of not random actions was  78
# The reward of the validation episode was  -2082.0
# The balanced accuracy was  0.2504973028462961
# Starting episode  5
# The episode duration was  100
# The episode reward was  -294.0
# The number of not random actions was  72
# The reward of the validation episode was  -2242.0
# The balanced accuracy was  0.18224889392176016
# Starting episode  6
# The episode duration was  100
# The episode reward was  -66.0
# The number of not random actions was  81
# The reward of the validation episode was  -998.0
# The balanced accuracy was  0.4266587800099157
# Starting episode  7
# The episode duration was  100
# The episode reward was  -91.0
# The number of not random actions was  79
# The reward of the validation episode was  208.0
# The balanced accuracy was  0.5634979861870902
# Starting episode  8
# The episode duration was  100
# The episode reward was  -22.0
# The number of not random actions was  75
# The reward of the validation episode was  75.0
# The balanced accuracy was  0.555229422565426
# Starting episode  9
# The episode duration was  100
# The episode reward was  -18.0
# The number of not random actions was  85
# The reward of the validation episode was  330.0
# The balanced accuracy was  0.5331693484534908
# Starting episode  10
# The episode duration was  100
# The episode reward was  21.0
# The number of not random actions was  71
# The reward of the validation episode was  667.0
# The balanced accuracy was  0.5873181423672029
# Starting episode  11
# The episode duration was  100
# The episode reward was  -58.0
# The number of not random actions was  76
# The reward of the validation episode was  412.0
# The balanced accuracy was  0.5798129920316517
# Starting episode  12
# The episode duration was  100
# The episode reward was  -9.0
# The number of not random actions was  86
# The reward of the validation episode was  1206.0
# The balanced accuracy was  0.6015703430363016
# Starting episode  13
# The episode duration was  100
# The episode reward was  16.0
# The number of not random actions was  73
# The reward of the validation episode was  1224.0
# The balanced accuracy was  0.6033659887284772
# Starting episode  14
# The episode duration was  100
# The episode reward was  19.0
# The number of not random actions was  82
# The reward of the validation episode was  1113.0
# The balanced accuracy was  0.6331898255432511
# Starting episode  15
# The episode duration was  100
# The episode reward was  -9.0
# The number of not random actions was  82
# The reward of the validation episode was  1597.0
# The balanced accuracy was  0.6269766819647762
# Starting episode  16
# The episode duration was  100
# The episode reward was  33.0
# The number of not random actions was  82
# The reward of the validation episode was  1937.0
# The balanced accuracy was  0.5941386336614726
# Starting episode  17
# The episode duration was  100
# The episode reward was  7.0
# The number of not random actions was  74
# The reward of the validation episode was  1751.0
# The balanced accuracy was  0.6118477741640851
# Starting episode  18
# The episode duration was  100
# The episode reward was  100.0
# The number of not random actions was  86
# The reward of the validation episode was  1848.0
# The balanced accuracy was  0.5664553816100382
# Starting episode  19
# The episode duration was  100
# The episode reward was  -2.0
# The number of not random actions was  76
# The reward of the validation episode was  1549.0
# The balanced accuracy was  0.46973190657563496
# Starting episode  20
# The episode duration was  100
# The episode reward was  28.0
# The number of not random actions was  82
# The reward of the validation episode was  1966.0
# The balanced accuracy was  0.6015338672060194
# Starting episode  21
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  84
# The reward of the validation episode was  2035.0
# The balanced accuracy was  0.6290873362619954
# Starting episode  22
# The episode duration was  100
# The episode reward was  43.0
# The number of not random actions was  77
# The reward of the validation episode was  2200.0
# The balanced accuracy was  0.5525133125413572
# Starting episode  23
# The episode duration was  100
# The episode reward was  25.0
# The number of not random actions was  74
# The reward of the validation episode was  2105.0
# The balanced accuracy was  0.6288397288070595
# Starting episode  24
# The episode duration was  100
# The episode reward was  91.0
# The number of not random actions was  81
# The reward of the validation episode was  2226.0
# The balanced accuracy was  0.7213093593500919
# Starting episode  25
# The episode duration was  100
# The episode reward was  -4.0
# The number of not random actions was  72
# The reward of the validation episode was  2554.0
# The balanced accuracy was  0.6696004738146781
# Starting episode  26
# The episode duration was  100
# The episode reward was  53.0
# The number of not random actions was  82
# The reward of the validation episode was  2611.0
# The balanced accuracy was  0.7276515736278094
# Starting episode  27
# The episode duration was  100
# The episode reward was  99.0
# The number of not random actions was  79
# The reward of the validation episode was  2178.0
# The balanced accuracy was  0.8391750327766578
# Starting episode  28
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  85
# The reward of the validation episode was  2646.0
# The balanced accuracy was  0.8102608316261618
# Starting episode  29
# The episode duration was  100
# The episode reward was  131.0
# The number of not random actions was  81
# The reward of the validation episode was  2285.0
# The balanced accuracy was  0.8493306611659516
# Starting episode  30
# The episode duration was  100
# The episode reward was  45.0
# The number of not random actions was  76
# The reward of the validation episode was  2590.0
# The balanced accuracy was  0.8549262439135062
# Starting episode  31
# The episode duration was  100
# The episode reward was  16.0
# The number of not random actions was  80
# The reward of the validation episode was  2628.0
# The balanced accuracy was  0.8438193146276541
# Starting episode  32
# The episode duration was  100
# The episode reward was  54.0
# The number of not random actions was  79
# The reward of the validation episode was  2206.0
# The balanced accuracy was  0.8544436798922538
# Starting episode  33
# The episode duration was  100
# The episode reward was  18.0
# The number of not random actions was  81
# The reward of the validation episode was  2600.0
# The balanced accuracy was  0.8486967711498574
# Starting episode  34
# The episode duration was  100
# The episode reward was  -27.0
# The number of not random actions was  80
# The reward of the validation episode was  2681.0
# The balanced accuracy was  0.85045125775194
# Starting episode  35
# The episode duration was  100
# The episode reward was  49.0
# The number of not random actions was  79
# The reward of the validation episode was  2402.0
# The balanced accuracy was  0.8372163668285652
# Starting episode  36
# The episode duration was  100
# The episode reward was  66.0
# The number of not random actions was  76
# The reward of the validation episode was  2796.0
# The balanced accuracy was  0.832180078754637
# Starting episode  37
# The episode duration was  100
# The episode reward was  -26.0
# The number of not random actions was  77
# The reward of the validation episode was  2224.0
# The balanced accuracy was  0.8198460389078669
# Starting episode  38
# The episode duration was  100
# The episode reward was  104.0
# The number of not random actions was  76
# The reward of the validation episode was  2310.0
# The balanced accuracy was  0.8392542290623272
# Starting episode  39
# The episode duration was  100
# The episode reward was  60.0
# The number of not random actions was  77
# The reward of the validation episode was  2476.0
# The balanced accuracy was  0.8173150103611772
# Starting episode  40
# The episode duration was  100
# The episode reward was  43.0
# The number of not random actions was  76
# The reward of the validation episode was  2458.0
# The balanced accuracy was  0.8269092540011627
# Starting episode  41
# The episode duration was  100
# The episode reward was  38.0
# The number of not random actions was  79
# The reward of the validation episode was  2299.0
# The balanced accuracy was  0.8499874097655631
# Starting episode  42
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  86
# The reward of the validation episode was  2540.0
# The balanced accuracy was  0.8400431102140878
# Starting episode  43
# The episode duration was  100
# The episode reward was  -17.0
# The number of not random actions was  74
# The reward of the validation episode was  2374.0
# The balanced accuracy was  0.841745892739695
# Starting episode  44
# The episode duration was  100
# The episode reward was  53.0
# The number of not random actions was  78
# The reward of the validation episode was  2376.0
# The balanced accuracy was  0.856130682129078
# Starting episode  45
# The episode duration was  100
# The episode reward was  18.0
# The number of not random actions was  77
# The reward of the validation episode was  2324.0
# The balanced accuracy was  0.7917814278924279
# Starting episode  46
# The episode duration was  100
# The episode reward was  46.0
# The number of not random actions was  84
# The reward of the validation episode was  2692.0
# The balanced accuracy was  0.8314900786110948
# Starting episode  47
# The episode duration was  100
# The episode reward was  142.0
# The number of not random actions was  80
# The reward of the validation episode was  2271.0
# The balanced accuracy was  0.8401045927495262
# Starting episode  48
# The episode duration was  100
# The episode reward was  74.0
# The number of not random actions was  87
# The reward of the validation episode was  2396.0
# The balanced accuracy was  0.8156120043397023
# Starting episode  49
# The episode duration was  100
# The episode reward was  53.0
# The number of not random actions was  84
# The reward of the validation episode was  2065.0
# The balanced accuracy was  0.8140044812563424
# Starting episode  50
# The episode duration was  100
# The episode reward was  36.0
# The number of not random actions was  73
# The reward of the validation episode was  2471.0
# The balanced accuracy was  0.8354573083604799
# Starting episode  51
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  78
# The reward of the validation episode was  2263.0
# The balanced accuracy was  0.7951697514703957
# Starting episode  52
# The episode duration was  100
# The episode reward was  72.0
# The number of not random actions was  86
# The reward of the validation episode was  2248.0
# The balanced accuracy was  0.8278270778499105
# Starting episode  53
# The episode duration was  100
# The episode reward was  7.0
# The number of not random actions was  81
# The reward of the validation episode was  2717.0
# The balanced accuracy was  0.8274006255387748
# Starting episode  54
# The episode duration was  100
# The episode reward was  88.0
# The number of not random actions was  82
# The reward of the validation episode was  2214.0
# The balanced accuracy was  0.8220111643057078
# Starting episode  55
# The episode duration was  100
# The episode reward was  86.0
# The number of not random actions was  91
# The reward of the validation episode was  2232.0
# The balanced accuracy was  0.8253799856991284
# Starting episode  56
# The episode duration was  100
# The episode reward was  61.0
# The number of not random actions was  82
# The reward of the validation episode was  2400.0
# The balanced accuracy was  0.7965485691721478
# Starting episode  57
# The episode duration was  100
# The episode reward was  106.0
# The number of not random actions was  76
# The reward of the validation episode was  2330.0
# The balanced accuracy was  0.8094049949232073
# Starting episode  58
# The episode duration was  100
# The episode reward was  36.0
# The number of not random actions was  81
# The reward of the validation episode was  2466.0
# The balanced accuracy was  0.8246285760410672
# Starting episode  59
# The episode duration was  100
# The episode reward was  41.0
# The number of not random actions was  70
# The reward of the validation episode was  2477.0
# The balanced accuracy was  0.8618206698921751
# Starting episode  60
# The episode duration was  100
# The episode reward was  3.0
# The number of not random actions was  75
# The reward of the validation episode was  2517.0
# The balanced accuracy was  0.8333064295414264
# Starting episode  61
# The episode duration was  100
# The episode reward was  82.0
# The number of not random actions was  81
# The reward of the validation episode was  2312.0
# The balanced accuracy was  0.8369850556599999
# Starting episode  62
# The episode duration was  100
# The episode reward was  44.0
# The number of not random actions was  79
# The reward of the validation episode was  2359.0
# The balanced accuracy was  0.8464804764016248
# Starting episode  63
# The episode duration was  100
# The episode reward was  42.0
# The number of not random actions was  75
# The reward of the validation episode was  2692.0
# The balanced accuracy was  0.7422651779133538
# Starting episode  64
# The episode duration was  100
# The episode reward was  80.0
# The number of not random actions was  77
# The reward of the validation episode was  2507.0
# The balanced accuracy was  0.8423702689761843
# Starting episode  65
# The episode duration was  100
# The episode reward was  29.0
# The number of not random actions was  84
# The reward of the validation episode was  2124.0
# The balanced accuracy was  0.7948296244321097
# Starting episode  66
# The episode duration was  100
# The episode reward was  84.0
# The number of not random actions was  82
# The reward of the validation episode was  2604.0
# The balanced accuracy was  0.8361446092491623
# Starting episode  67
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  76
# The reward of the validation episode was  2271.0
# The balanced accuracy was  0.8245967676716291
# Starting episode  68
# The episode duration was  100
# The episode reward was  -2.0
# The number of not random actions was  78
# The reward of the validation episode was  2608.0
# The balanced accuracy was  0.7286708713842346
# Starting episode  69
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  80
# The reward of the validation episode was  2433.0
# The balanced accuracy was  0.7522666451778189
# Starting episode  70
# The episode duration was  100
# The episode reward was  30.0
# The number of not random actions was  81
# The reward of the validation episode was  2603.0
# The balanced accuracy was  0.7285671163239754
# Starting episode  71
# The episode duration was  100
# The episode reward was  5.0
# The number of not random actions was  76
# The reward of the validation episode was  2636.0
# The balanced accuracy was  0.7329260310855747
# Starting episode  72
# The episode duration was  100
# The episode reward was  60.0
# The number of not random actions was  81
# The reward of the validation episode was  2528.0
# The balanced accuracy was  0.7388840038650369
# Starting episode  73
# The episode duration was  100
# The episode reward was  55.0
# The number of not random actions was  79
# The reward of the validation episode was  2228.0
# The balanced accuracy was  0.8194788262015996
# Starting episode  74
# The episode duration was  100
# The episode reward was  98.0
# The number of not random actions was  81
# The reward of the validation episode was  2247.0
# The balanced accuracy was  0.7313861668505418
# Starting episode  75
# The episode duration was  100
# The episode reward was  91.0
# The number of not random actions was  80
# The reward of the validation episode was  2418.0
# The balanced accuracy was  0.8355003143474471
# Starting episode  76
# The episode duration was  100
# The episode reward was  101.0
# The number of not random actions was  82
# The reward of the validation episode was  2773.0
# The balanced accuracy was  0.8527493318796288
# Starting episode  77
# The episode duration was  100
# The episode reward was  99.0
# The number of not random actions was  85
# The reward of the validation episode was  2239.0
# The balanced accuracy was  0.8306125934672782
# Starting episode  78
# The episode duration was  100
# The episode reward was  60.0
# The number of not random actions was  87
# The reward of the validation episode was  2251.0
# The balanced accuracy was  0.8468854464038712
# Starting episode  79
# The episode duration was  100
# The episode reward was  11.0
# The number of not random actions was  80
# The reward of the validation episode was  2256.0
# The balanced accuracy was  0.8466385624404313
# Starting episode  80
# The episode duration was  100
# The episode reward was  104.0
# The number of not random actions was  82
# The reward of the validation episode was  2345.0
# The balanced accuracy was  0.7915642029177595
# Starting episode  81
# The episode duration was  100
# The episode reward was  35.0
# The number of not random actions was  85
# The reward of the validation episode was  2169.0
# The balanced accuracy was  0.8056518819060284
# Starting episode  82
# The episode duration was  100
# The episode reward was  47.0
# The number of not random actions was  79
# The reward of the validation episode was  2660.0
# The balanced accuracy was  0.7932622744617183
# Starting episode  83
# The episode duration was  100
# The episode reward was  43.0
# The number of not random actions was  80
# The reward of the validation episode was  2354.0
# The balanced accuracy was  0.8269974993661016
# Starting episode  84
# The episode duration was  100
# The episode reward was  85.0
# The number of not random actions was  75
# The reward of the validation episode was  2456.0
# The balanced accuracy was  0.8516649155081043
# Starting episode  85
# The episode duration was  100
# The episode reward was  52.0
# The number of not random actions was  84
# The reward of the validation episode was  2762.0
# The balanced accuracy was  0.8543633884515908
# Starting episode  86
# The episode duration was  100
# The episode reward was  55.0
# The number of not random actions was  79
# The reward of the validation episode was  2767.0
# The balanced accuracy was  0.856456230284704
# Starting episode  87
# The episode duration was  100
# The episode reward was  59.0
# The number of not random actions was  85
# The reward of the validation episode was  2687.0
# The balanced accuracy was  0.8551027403240573
# Starting episode  88
# The episode duration was  100
# The episode reward was  95.0
# The number of not random actions was  79
# The reward of the validation episode was  2724.0
# The balanced accuracy was  0.8660383772925352
# Starting episode  89
# The episode duration was  100
# The episode reward was  84.0
# The number of not random actions was  85
# The reward of the validation episode was  2349.0
# The balanced accuracy was  0.840392814021561
# Starting episode  90
# The episode duration was  100
# The episode reward was  47.0
# The number of not random actions was  78
# The reward of the validation episode was  2298.0
# The balanced accuracy was  0.858093062155049
# Starting episode  91
# The episode duration was  100
# The episode reward was  141.0
# The number of not random actions was  86
# The reward of the validation episode was  2703.0
# The balanced accuracy was  0.8518354127743368
# Starting episode  92
# The episode duration was  100
# The episode reward was  105.0
# The number of not random actions was  81
# The reward of the validation episode was  2246.0
# The balanced accuracy was  0.8567305410800089
# Starting episode  93
# The episode duration was  100
# The episode reward was  139.0
# The number of not random actions was  76
# The reward of the validation episode was  2696.0
# The balanced accuracy was  0.8420732085853432
# Starting episode  94
# The episode duration was  100
# The episode reward was  35.0
# The number of not random actions was  82
# The reward of the validation episode was  2152.0
# The balanced accuracy was  0.8618996677773786
# Starting episode  95
# The episode duration was  100
# The episode reward was  26.0
# The number of not random actions was  84
# The reward of the validation episode was  2477.0
# The balanced accuracy was  0.8310741036467889
# Starting episode  96
# The episode duration was  100
# The episode reward was  22.0
# The number of not random actions was  84
# The reward of the validation episode was  2395.0
# The balanced accuracy was  0.8542986938845016
# Starting episode  97
# The episode duration was  100
# The episode reward was  28.0
# The number of not random actions was  84
# The reward of the validation episode was  2187.0
# The balanced accuracy was  0.8501381022498676
# Starting episode  98
# The episode duration was  100
# The episode reward was  29.0
# The number of not random actions was  80
# The reward of the validation episode was  2313.0
# The balanced accuracy was  0.854694353307458
# Starting episode  99
# The episode duration was  100
# The episode reward was  6.0
# The number of not random actions was  81
# The reward of the validation episode was  2746.0
# The balanced accuracy was  0.8473804864815903
# Starting episode  100
# The episode duration was  100
# The episode reward was  84.0
# The number of not random actions was  71
# The reward of the validation episode was  2354.0
# The balanced accuracy was  0.8319682774064033
# Starting episode  101
# The episode duration was  100
# The episode reward was  55.0
# The number of not random actions was  77
# The reward of the validation episode was  2733.0
# The balanced accuracy was  0.8356056236368143
# Starting episode  102
# The episode duration was  100
# The episode reward was  51.0
# The number of not random actions was  81
# The reward of the validation episode was  2263.0
# The balanced accuracy was  0.8434807771449337
# Starting episode  103
# The episode duration was  100
# The episode reward was  33.0
# The number of not random actions was  84
# The reward of the validation episode was  2375.0
# The balanced accuracy was  0.8458950970534925
# Starting episode  104
# The episode duration was  100
# The episode reward was  106.0
# The number of not random actions was  85
# The reward of the validation episode was  2227.0
# The balanced accuracy was  0.838693733088359
# Starting episode  105
# The episode duration was  100
# The episode reward was  88.0
# The number of not random actions was  88
# The reward of the validation episode was  2270.0
# The balanced accuracy was  0.8049072087034537
# Starting episode  106
# The episode duration was  100
# The episode reward was  50.0
# The number of not random actions was  79
# The reward of the validation episode was  2573.0
# The balanced accuracy was  0.8019248075587216
# Starting episode  107
# The episode duration was  100
# The episode reward was  45.0
# The number of not random actions was  79
# The reward of the validation episode was  2594.0
# The balanced accuracy was  0.8463455496555479
# Starting episode  108
# The episode duration was  100
# The episode reward was  83.0
# The number of not random actions was  82
# The reward of the validation episode was  2473.0
# The balanced accuracy was  0.8297381377937528
# Starting episode  109
# The episode duration was  100
# The episode reward was  12.0
# The number of not random actions was  74
# The reward of the validation episode was  2611.0
# The balanced accuracy was  0.8433715288962921
# Starting episode  110
# The episode duration was  100
# The episode reward was  97.0
# The number of not random actions was  77
# The reward of the validation episode was  2520.0
# The balanced accuracy was  0.8272399566396128
# Starting episode  111
# The episode duration was  100
# The episode reward was  66.0
# The number of not random actions was  83
# The reward of the validation episode was  2427.0
# The balanced accuracy was  0.8509009342984333
# Starting episode  112
# The episode duration was  100
# The episode reward was  53.0
# The number of not random actions was  76
# The reward of the validation episode was  2596.0
# The balanced accuracy was  0.7826591653360612
# Starting episode  113
# The episode duration was  100
# The episode reward was  27.0
# The number of not random actions was  79
# The reward of the validation episode was  2472.0
# The balanced accuracy was  0.8398325109909457
# Starting episode  114
# The episode duration was  100
# The episode reward was  41.0
# The number of not random actions was  79
# The reward of the validation episode was  2482.0
# The balanced accuracy was  0.8225302441989096
# Starting episode  115
# The episode duration was  100
# The episode reward was  59.0
# The number of not random actions was  84
# The reward of the validation episode was  2361.0
# The balanced accuracy was  0.8464577711175679
# Starting episode  116
# The episode duration was  100
# The episode reward was  87.0
# The number of not random actions was  81
# The reward of the validation episode was  2424.0
# The balanced accuracy was  0.8341720655456545
# Starting episode  117
# The episode duration was  100
# The episode reward was  63.0
# The number of not random actions was  80
# The reward of the validation episode was  2668.0
# The balanced accuracy was  0.8239086220508741
# Starting episode  118
# The episode duration was  100
# The episode reward was  74.0
# The number of not random actions was  79
# The reward of the validation episode was  2354.0
# The balanced accuracy was  0.8509426045297476
# Starting episode  119
# The episode duration was  100
# The episode reward was  104.0
# The number of not random actions was  84
# The reward of the validation episode was  2670.0
# The balanced accuracy was  0.8293181215837169
# Starting episode  120
# The episode duration was  100
# The episode reward was  57.0
# The number of not random actions was  79
# The reward of the validation episode was  2523.0
# The balanced accuracy was  0.8367426493445277
# Starting episode  121
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  84
# The reward of the validation episode was  2396.0
# The balanced accuracy was  0.8288928235053838
# Starting episode  122
# The episode duration was  100
# The episode reward was  65.0
# The number of not random actions was  77
# The reward of the validation episode was  2759.0
# The balanced accuracy was  0.8653110965221208
# Starting episode  123
# The episode duration was  100
# The episode reward was  46.0
# The number of not random actions was  79
# The reward of the validation episode was  2628.0
# The balanced accuracy was  0.8559099528482148
# Starting episode  124
# The episode duration was  100
# The episode reward was  117.0
# The number of not random actions was  78
# The reward of the validation episode was  2280.0
# The balanced accuracy was  0.8461711269192423
# Starting episode  125
# The episode duration was  100
# The episode reward was  107.0
# The number of not random actions was  78
# The reward of the validation episode was  2730.0
# The balanced accuracy was  0.8535729085864988
# Starting episode  126
# The episode duration was  100
# The episode reward was  107.0
# The number of not random actions was  84
# The reward of the validation episode was  2733.0
# The balanced accuracy was  0.8350295548679715
# Starting episode  127
# The episode duration was  100
# The episode reward was  70.0
# The number of not random actions was  82
# The reward of the validation episode was  2753.0
# The balanced accuracy was  0.8484506097727345
# Starting episode  128
# The episode duration was  100
# The episode reward was  -2.0
# The number of not random actions was  76
# The reward of the validation episode was  2236.0
# The balanced accuracy was  0.8489597913436961
# Starting episode  129
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  82
# The reward of the validation episode was  2596.0
# The balanced accuracy was  0.8642212010075104
# Starting episode  130
# The episode duration was  100
# The episode reward was  60.0
# The number of not random actions was  85
# The reward of the validation episode was  2263.0
# The balanced accuracy was  0.8379557283427631
# Starting episode  131
# The episode duration was  100
# The episode reward was  63.0
# The number of not random actions was  83
# The reward of the validation episode was  2701.0
# The balanced accuracy was  0.8412820711372702
# Starting episode  132
# The episode duration was  100
# The episode reward was  -18.0
# The number of not random actions was  82
# The reward of the validation episode was  2576.0
# The balanced accuracy was  0.8554860516912715
# Starting episode  133
# The episode duration was  100
# The episode reward was  102.0
# The number of not random actions was  82
# The reward of the validation episode was  2736.0
# The balanced accuracy was  0.849763459099201
# Starting episode  134
# The episode duration was  100
# The episode reward was  47.0
# The number of not random actions was  78
# The reward of the validation episode was  2326.0
# The balanced accuracy was  0.8330097400245565
# Starting episode  135
# The episode duration was  100
# The episode reward was  39.0
# The number of not random actions was  83
# The reward of the validation episode was  2677.0
# The balanced accuracy was  0.8415098735846531
# Starting episode  136
# The episode duration was  100
# The episode reward was  74.0
# The number of not random actions was  84
# The reward of the validation episode was  2439.0
# The balanced accuracy was  0.8578491514049874
# Starting episode  137
# The episode duration was  100
# The episode reward was  125.0
# The number of not random actions was  85
# The reward of the validation episode was  2739.0
# The balanced accuracy was  0.8319298190931516
# Starting episode  138
# The episode duration was  100
# The episode reward was  113.0
# The number of not random actions was  87
# The reward of the validation episode was  2672.0
# The balanced accuracy was  0.8035847065310009
# Starting episode  139
# The episode duration was  100
# The episode reward was  21.0
# The number of not random actions was  72
# The reward of the validation episode was  2221.0
# The balanced accuracy was  0.8391117540674017
# Starting episode  140
# The episode duration was  100
# The episode reward was  64.0
# The number of not random actions was  88
# The reward of the validation episode was  2567.0
# The balanced accuracy was  0.8516731831738023
# Starting episode  141
# The episode duration was  100
# The episode reward was  6.0
# The number of not random actions was  77
# The reward of the validation episode was  2237.0
# The balanced accuracy was  0.8532576552277649
# Starting episode  142
# The episode duration was  100
# The episode reward was  -22.0
# The number of not random actions was  81
# The reward of the validation episode was  2667.0
# The balanced accuracy was  0.815251185822225
# Starting episode  143
# The episode duration was  100
# The episode reward was  4.0
# The number of not random actions was  80
# The reward of the validation episode was  2461.0
# The balanced accuracy was  0.8113717585025695
# Starting episode  144
# The episode duration was  100
# The episode reward was  81.0
# The number of not random actions was  82
# The reward of the validation episode was  2688.0
# The balanced accuracy was  0.8444553049623513
# Starting episode  145
# The episode duration was  100
# The episode reward was  115.0
# The number of not random actions was  86
# The reward of the validation episode was  2225.0
# The balanced accuracy was  0.8428464663545675
# Starting episode  146
# The episode duration was  100
# The episode reward was  109.0
# The number of not random actions was  79
# The reward of the validation episode was  2551.0
# The balanced accuracy was  0.7968751296888507
# Starting episode  147
# The episode duration was  100
# The episode reward was  49.0
# The number of not random actions was  82
# The reward of the validation episode was  2726.0
# The balanced accuracy was  0.8452934410002066
# Starting episode  148
# The episode duration was  100
# The episode reward was  124.0
# The number of not random actions was  87
# The reward of the validation episode was  2242.0
# The balanced accuracy was  0.8334796910757258
# Starting episode  149
# The episode duration was  100
# The episode reward was  24.0
# The number of not random actions was  82
# The reward of the validation episode was  2237.0
# The balanced accuracy was  0.8560140276169017
# The scores for best validation BAcc are:
#               precision    recall  f1-score   support
#
#          0.0      0.917     0.677     0.779        65
#          1.0      0.765     0.981     0.860       103
#          2.0      0.793     0.800     0.796       220
#          3.0      0.955     0.913     0.933        23
#          4.0      0.619     0.830     0.709       223
#          5.0      0.963     0.898     0.929      1341
#          6.0      0.900     0.964     0.931        28
#
#     accuracy                          0.878      2003
#    macro avg      0.844     0.866     0.848      2003
# weighted avg      0.893     0.878     0.882      2003
#
# [[  44    4   10    0    7    0    0]
#  [   0  101    0    0    1    1    0]
#  [   3    8  176    0   18   15    0]
#  [   0    0    0   21    0    2    0]
#  [   0    4    5    0  185   28    1]
#  [   1   15   31    1   87 1204    2]
#  [   0    0    0    0    1    0   27]]
# The best BAcc was  0.8660383772925352
# The scores for best validation Reward are:
#               precision    recall  f1-score   support
#
#          0.0      0.915     0.662     0.768        65
#          1.0      0.843     0.942     0.890       103
#          2.0      0.846     0.750     0.795       220
#          3.0      1.000     0.739     0.850        23
#          4.0      0.557     0.879     0.682       223
#          5.0      0.956     0.890     0.922      1341
#          6.0      0.931     0.964     0.947        28
#
#     accuracy                          0.868      2003
#    macro avg      0.864     0.832     0.836      2003
# weighted avg      0.892     0.868     0.874      2003
#
# [[  43    2    8    0   12    0    0]
#  [   0   97    1    0    4    1    0]
#  [   3    4  165    0   24   24    0]
#  [   0    0    0   17    0    6    0]
#  [   0    1    2    0  196   24    0]
#  [   1   11   19    0  115 1193    2]
#  [   0    0    0    0    1    0   27]]
# The best reward was  2796.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\nihal\anaconda3\envs\rl-env\Lib\site-packages\IPython\core\interactiveshell.py:3675: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
